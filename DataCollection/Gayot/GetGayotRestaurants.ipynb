# %%
import math
import sys
import fileinput
from lxml import html  
import unicodecsv as csv
import requests
from time import sleep
import re
import argparse
import pandas as pd
import numpy as np
from urllib.parse import quote, unquote
import re, urllib

# %%
def GetParser(url):
    response = requests.get(url).text
    parser = html.fromstring(response)
    return parser

# %%
def BusinessInfoScrapper(parser):
    raw_name = parser.xpath("//h1[contains(@class,'page-title')]//text()")
    raw_claimed = parser.xpath("//span[contains(@class,'claim-status_icon--claimed')]/parent::div/text()")
    raw_reviews = parser.xpath("//div[contains(@class,'biz-main-info')]//span[contains(@class,'review-count rating-qualifier')]//text()")
    raw_category  = parser.xpath('//div[contains(@class,"biz-page-header")]//span[@class="category-str-list"]//a/text()')
    hours_table = parser.xpath("//table[contains(@class,'hours-table')]//tr")
    details_table = parser.xpath("//div[@class='short-def-list']//dl")
    raw_map_link = parser.xpath("//a[@class='biz-map-directions']/img/@src")
    raw_phone = parser.xpath(".//span[@class='biz-phone']//text()")
    raw_address = parser.xpath('//div[@class="mapbox-text"]//div[contains(@class,"map-box-address")]//text()')
    raw_wbsite_link = parser.xpath("//span[contains(@class,'biz-website')]/a/@href")
    raw_price_range = parser.xpath("//dd[contains(@class,'price-description')]//text()")
    raw_health_rating = parser.xpath("//dd[contains(@class,'health-score-description')]//text()")
    rating_histogram = parser.xpath("//table[contains(@class,'histogram')]//tr[contains(@class,'histogram_row')]")
    raw_ratings = parser.xpath("//div[contains(@class,'biz-page-header')]//div[contains(@class,'rating')]/@title")
    raw_neighborhood = parser.xpath("//div[@class='map-box-address u-space-l4']/span[@class='neighborhood-str-list']//text()")
    report = parser.xpath('//p[contains(@class,"alert-message text-centered")]/b/text()')
    working_hours = []
    
    for hours in hours_table:
        raw_day = hours.xpath(".//th//text()")
        raw_timing = hours.xpath("./td//text()")
        day = ''.join(raw_day).strip()
        timing = ''.join(raw_timing).strip()
        working_hours.append({day:timing})
    info = []
    for details in details_table:
        raw_description_key = details.xpath('.//dt//text()')
        raw_description_value = details.xpath('.//dd//text()')
        description_key = ''.join(raw_description_key).strip()
        description_value = ''.join(raw_description_value).strip()
        info.append({description_key:description_value})

    ratings_histogram = [] 
    for ratings in rating_histogram:
        raw_rating_key = ratings.xpath(".//th//text()")
        raw_rating_value = ratings.xpath(".//td[@class='histogram_count']//text()")
        rating_key = ''.join(raw_rating_key).strip()
        rating_value = ''.join(raw_rating_value).strip()
        ratings_histogram.append({int(rating_key[0]):int(rating_value)})

    name = ''.join(raw_name).strip()
    phone = ''.join(raw_phone).strip()
    address = ' '.join(' '.join(raw_address).split())
    health_rating = ''.join(raw_health_rating).strip()
    price_range = ''.join(raw_price_range).strip()
    claimed_status = ''.join(raw_claimed).strip()
    category = ','.join(raw_category)
    cleaned_ratings = ''.join(raw_ratings).strip()

    if raw_wbsite_link:
        #pass
        decoded_raw_website_link = urllib.parse.unquote(raw_wbsite_link[0])
        website = re.findall("biz_redir\?url=(.*)&website_link",decoded_raw_website_link)[0]
    else:
        website = ''

    if raw_map_link:
        decoded_map_url =  urllib.parse.unquote(raw_map_link[0])
        map_coordinates = re.findall("([+-]?\d+.\d+,[+-]?\d+\.\d+)",decoded_map_url)[0].split(',')
        latitude = float(map_coordinates[0])
        longitude = float(map_coordinates[1])
    else:
        latitude = ''
        longitude = ''

    if raw_ratings:
        ratings = float(re.findall("\d+[.,]?\d+",cleaned_ratings)[0])
    else:
        ratings = 0

    if raw_neighborhood:
        neighborhood = ''.join(raw_neighborhood).strip()
    else:
        neighborhood = ''

    if raw_reviews:
        reviews = int(''.join(raw_reviews).strip().replace(' reviews','').replace(' review',''))
    else:
        reviews = ''

    if report == []:
        permanently_closed = 0
    else:
        permanently_closed = 1

    data={'working_hours':working_hours,
        'info':info,
        'ratings_histogram':ratings_histogram,
        'name':name,
        'phone':phone,
        'ratings':ratings,
        'address':address,
        'health_rating':health_rating,
        'price_range':price_range,
        'claimed_status':claimed_status,
        'reviews':reviews,
        'category':category,
        'website':website,
        'latitude':latitude,
        'longitude':longitude,
        'neighborhood': neighborhood,  
        'permanently_closed': permanently_closed 
         }
    return data

# %%
def GetAllReivews(parser):
    '''Given the parsed first webpage of a restaurant on yelp, return all reviews of that restaurants'''
    review_dict = {'date': [], 'star': [], 'text': []}
    
    review_dates = parser.xpath("//div[@class='review-content']//span[@class='rating-qualifier']")
    for d in review_dates:
        date = ''.join(d.xpath(".//text()")).strip().split('\n')[0]
        review_dict['date'].append(date)    

    review_stars = parser.xpath("//div[@class='review review--with-sidebar']/div[@class='review-wrapper']/div[@class='review-content']/div[@class='biz-rating biz-rating-large clearfix']")
    for s in review_stars:
        star = float(''.join(s.xpath(".//@title")).strip().replace(' star rating',''))
        review_dict['star'].append(star)
        
    review_texts = parser.xpath("//div[@class='review review--with-sidebar']/div[@class='review-wrapper']/div[@class='review-content']/p")
    for t in review_texts:
        text = ' '.join(t.xpath(".//text()"))
        review_dict['text'].append(text)
    
    review = pd.DataFrame(review_dict)
    review['date'] =  pd.to_datetime(review['date'])
    
    review_pages_section = parser.xpath("//div[@class='arrange arrange--stack arrange--baseline arrange--6']//text()")     
    review_pages = [item for item in [e.replace('\n','').replace(' ','') for e in review_pages_section] if item != '' ]

    if 'Next' not in review_pages:
        return review
    else:
        nextpage = parser.xpath('//a[@class="u-decoration-none next pagination-links_anchor"]/@href')[0]
        nextparser = GetParser(nextpage)
        sleep(1)
        return review.append(GetAllReivews(nextparser), ignore_index=True)

# %%
import os
os.getcwd()
# Out:
# '/Users/cysung/GA/projects/project_capstone/part_02/Gayot'

# %%
def GetAllRestaurants(path='./',listfile='./gayot_list_nochain.txt', start=497, end=None, GetReviews=True):
    import random
    yelp_url = 'https://www.yelp.com/biz/'
    restaurants = [line.strip() for line in open(listfile)]
    if end == None:
        end = len(restaurants)
    if start == 0 :
        file = open("did_not_work.txt", "w+")
        file.close()
    for i, r in enumerate(restaurants[start:end]):
        keyword = r.lower().replace('\'','').replace('&', 'and').replace(',','').replace(' ','-')
        url = yelp_url + keyword + '-chicago'
        response = requests.get(url)
        sleep(random.choice([1,2]))
        if response.status_code == 200:    
            parsed = html.fromstring(response.text)
            data = BusinessInfoScrapper(parsed)
            restaurant = pd.DataFrame({k:[v] for k, v in data.items()})
            restaurant['url'] = url
            restaurant.to_csv(path+str(i+start)+'_'+keyword+'.csv', index=False)
            if GetReviews:
                reviews = GetAllReivews(parsed).sort_values(by='date', ascending=False).reset_index(drop=True)
                reviews.to_csv(path+str(i+start)+'_'+keyword+'_review.csv', index=False)        
            print('got '+str(i+start)+': '+url)
        else:
            with open("did_not_work.txt","a+") as file:
                file.write(str(i+start)+': '+keyword+'\n')            
            print('didn\'t get '+str(i+start)+': '+url)

# %%
GetAllRestaurants(path='./',listfile='./gayot_list_nochain.txt', start=497, end=None, GetReviews=False)
# Out:
# didn't get 497: https://www.yelp.com/biz/sweet-water-chicago
# got 498: https://www.yelp.com/biz/sweets-and-savories-chicago
# got 499: https://www.yelp.com/biz/szechwan-east-chicago
# got 500: https://www.yelp.com/biz/takashi-chicago
# got 501: https://www.yelp.com/biz/tallulah-chicago
# got 502: https://www.yelp.com/biz/the-tasting-room-chicago
# didn't get 503: https://www.yelp.com/biz/tasty-dog-chicago
# got 504: https://www.yelp.com/biz/tavernita-chicago
# didn't get 505: https://www.yelp.com/biz/taylor-rose-chicago
# didn't get 506: https://www.yelp.com/biz/technicolor-kitchen-chicago
# got 507: https://www.yelp.com/biz/telegraph-chicago
# got 508: https://www.yelp.com/biz/tepatulco-chicago
# didn't get 509: https://www.yelp.com/biz/thai-classic-chicago
# didn't get 510: https://www.yelp.com/biz/302-west-chicago
# didn't get 511: https://www.yelp.com/biz/thyme-chicago
# didn't get 512: https://www.yelp.com/biz/tibet-cafe-chicago
# got 513: https://www.yelp.com/biz/timo-chicago
# didn't get 514: https://www.yelp.com/biz/tin-fish-chicago
# got 515: https://www.yelp.com/biz/tizi-melloul-chicago
# got 516: https://www.yelp.com/biz/tokyo-21-chicago
# didn't get 517: https://www.yelp.com/biz/tonic-661-chicago
# didn't get 518: https://www.yelp.com/biz/tonys-eatin-house-chicago
# didn't get 519: https://www.yelp.com/biz/tournesol-chicago
# got 520: https://www.yelp.com/biz/trader-vics-chicago
# didn't get 521: https://www.yelp.com/biz/tramontos-steak-and-seafood-chicago
# didn't get 522: https://www.yelp.com/biz/treat-chicago
# didn't get 523: https://www.yelp.com/biz/trio-atelier-chicago
# didn't get 524: https://www.yelp.com/biz/trucchi-italian-bistro-chicago
# got 525: https://www.yelp.com/biz/tsuki-japanese-restaurant-and-lounge-chicago
# didn't get 526: https://www.yelp.com/biz/tsunami-chicago
# didn't get 527: https://www.yelp.com/biz/tuscany-on-clark-chicago
# didn't get 528: https://www.yelp.com/biz/200-east-on-chestnut-chicago
# got 529: https://www.yelp.com/biz/urban-union-chicago
# got 530: https://www.yelp.com/biz/urbanbelly-chicago
# didn't get 531: https://www.yelp.com/biz/valley-lodge-chicago
# got 532: https://www.yelp.com/biz/veerasway-chicago
# didn't get 533: https://www.yelp.com/biz/vesuvio-cafe-chicago
# got 534: https://www.yelp.com/biz/via-veneto-chicago
# got 535: https://www.yelp.com/biz/via-ventuno-chicago
# didn't get 536: https://www.yelp.com/biz/vietnam-little-home-restaurant-chicago
# got 537: https://www.yelp.com/biz/vongs-thai-kitchen-chicago
# didn't get 538: https://www.yelp.com/biz/watusi-chicago
# got 539: https://www.yelp.com/biz/wave-chicago
# got 540: https://www.yelp.com/biz/weber-grill-restaurant-chicago
# got 541: https://www.yelp.com/biz/west-town-tavern-chicago
# got 542: https://www.yelp.com/biz/winstons-market-chicago
# didn't get 543: https://www.yelp.com/biz/wolfgang-puck-grand-cafe-chicago
# didn't get 544: https://www.yelp.com/biz/woo-lae-oak-chicago
# didn't get 545: https://www.yelp.com/biz/x/o-chicago-chicago
# got 546: https://www.yelp.com/biz/xel-ha-chicago
# didn't get 547: https://www.yelp.com/biz/yannis-greek-restaurant-chicago
# didn't get 548: https://www.yelp.com/biz/zaidis-chicago
# didn't get 549: https://www.yelp.com/biz/zaks-place-chicago
# got 550: https://www.yelp.com/biz/zapatista-chicago
# didn't get 551: https://www.yelp.com/biz/zavens-chicago
# didn't get 552: https://www.yelp.com/biz/zealous-chicago
# got 553: https://www.yelp.com/biz/zed451-chicago
# got 554: https://www.yelp.com/biz/zest-chicago
# didn't get 555: https://www.yelp.com/biz/zinfandel-chicago
# didn't get 556: https://www.yelp.com/biz/zkf-chicago
# didn't get 557: https://www.yelp.com/biz/zocalo-mexican-grill-and-tequileria-chicago
# got 558: https://www.yelp.com/biz/zoom-kitchen-chicago

# %%
updated_restaurants = [line.strip() for line in open('updated_list.txt')]

# %%
import random
yelp_url = 'https://www.yelp.com/biz/'
reviewfiles = [f for f in listdir('./') if '_review.csv' in f]

for r in updated_restaurants[55:]:
    number = r.split(': ')[0]
    keyword = r.split(': ')[1].lower().replace(' ', '-').replace('\'','').replace('&', 'and').replace(',','')    
    url = yelp_url + keyword + '-chicago'
    response = requests.get(url)
    sleep(1)
    if response.status_code == 200:    
        parsed = html.fromstring(response.text)
        data = BusinessInfoScrapper(parsed)
        restaurant = pd.DataFrame({k:[v] for k, v in data.items()})
        restaurant.to_csv(str(number)+'_'+keyword+'.csv', index=False)
        if str(number)+'_'+keyword+'_review.csv' not in reviewfiles:
            reviews = GetAllReivews(parsed).sort_values(by='date', ascending=False).reset_index(drop=True)
            reviews.to_csv(str(number)+'_'+keyword+'_review.csv', index=False)        
        print('Got ', number, ':', keyword)
    else:
        print('Didn\'t get ', number, ':', keyword)
# Out:
# Got  296 : kyoto-sushi-steak-seafood
# Got  302 : la-donna-italian-cuisine
# Got  305 : la-strada-ristorante
# Got  308 : la-vita-restaurant
# Got  310 : landmark-grill
# Got  322 : lindo-mexico-restauant
# Got  332 : magnums-prime-steakhouse
# Got  346 : mi-peru-restaurant-and-club
# Got  352 : mk-restaurant
# Got  358 : moon-palace-restaurant
# Got  360 : moti-mahal-indian-restaurant
# Got  368 : cafe-nhu-hoa
# Got  371 : rylons-smokehouse
# Didn't get  375 : nuevo-leon-restaurant-chicago-2
# Got  383 : one-six-one
# Got  388 : leons-bar-b-q
# Got  399 : papagus-greek-taverna
# Got  404 : the-parthenon
# Got  417 : p-j-clarkes
# Got  427 : province
# Got  455 : sabor-a-cuba-restaurant
# Got  481 : terragusto
# Got  486 : pump-room
# Got  496 : swank-frank-inc
# Got  506 : veggie-bite
# Got  509 : thai-classic-restaurant
# Got  511 : thyme-restaurant
# Got  519 : tournesol-french-bistro
# Got  522 : treat-restaurant
# Got  526 : tsunami-japanese-restaurant
# Got  527 : tuscany-restaurant
# Got  545 : x-o-chicago
# Got  551 : thong-thai
# Got  552 : zealous-restaurant
# Got  555 : osteria-la-madia
# Got  556 : zk-food
# Got  557 : zocalo

# %%
def GetRestaurant(number=None, keyword=None, postfix=''):
    yelp_url = 'https://www.yelp.com/biz/'
    url = yelp_url + keyword + '-chicago' + postfix
    response = requests.get(url)
    sleep(1)
    if response.status_code == 200:    
        parsed = html.fromstring(response.text)
        data = BusinessInfoScrapper(parsed)
        restaurant = pd.DataFrame({k:[v] for k, v in data.items()})
        restaurant.to_csv(str(number)+'_'+keyword+'.csv', index=False)
        reviews = GetAllReivews(parsed).sort_values(by='date', ascending=False).reset_index(drop=True)
        reviews.to_csv(str(number)+'_'+keyword+'_review.csv', index=False)        
        print('Got ', number, ':', keyword)
    else:
        print('Didn\'t get ', number, ':', keyword)

# %%
GetRestaurant(number=371, keyword='rylons-smokehouse', postfix=None)
# Out:
# Got  371 : rylons-smokehouse

# %%
GetRestaurant(number=375, keyword='nuevo-leon-restaurant', postfix='-2')
# Out:
# Got  375 : nuevo-leon-restaurant

# %%
GetRestaurant(number=20, keyword='ambria', postfix='-2')
# Out:
# Got  20 : ambria

# %%
GetRestaurant(number=482, keyword='spring-restaurant', postfix='')
# Out:
# Got  482 : spring-restaurant

# %%
GetRestaurant(number=198, keyword='fahrenheit', postfix='-2')
# Out:
# Got  198 : fahrenheit

# %%
from os import listdir
from os.path import isfile, join

# %%
infofiles = [f for f in listdir('./') if '_review.csv' not in f]
infofiles = [f for f in infofiles if '.csv' in f]

# %%
infofiles
# Out:
# ['0_2-sparrows.csv',
#  '100_coq-d-or-restaurant-and-lounge.csv',
#  '101_cafe-laguardia.csv',
#  '103_cafe-luciano.csv',
#  '104_cafe-matou.csv',
#  '105_cafe-chien.csv',
#  '106_cafe-selmarie.csv',
#  '107_caffe-baci.csv',
#  '108_caliterra.csv',
#  '109_cambridge-house-ltd.csv',
#  '10_adobo-grill.csv',
#  '110_cannellas-on-grand.csv',
#  '113_cantina-1910.csv',
#  '114_calo-ristorante.csv',
#  '115_filippos-ristorante.csv',
#  '116_carmichaels-chicago-steakhouse.csv',
#  '117_carriage-house.csv',
#  '118_centro.csv',
#  '119_cereality-cereal-bar-and-cafe.csv',
#  '11_aigre-doux.csv',
#  '120_ceres-table.csv',
#  '121_cerise.csv',
#  '122_chalkboard.csv',
#  '123_charlies-ale-house.csv',
#  '124_charlies-on-leavitt.csv',
#  '125_charlie-trotters.csv',
#  '126_chicago-flat-sammies.csv',
#  '127_chickpea.csv',
#  '128_chilapan.csv',
#  '129_chilpancingo.csv',
#  '12_aja.csv',
#  '130_china-grill.csv',
#  '131_chizakaya-japanese-pub.csv',
#  '133_cibo-matto.csv',
#  '134_cicchetti.csv',
#  '135_city-tavern.csv',
#  '137_nouveau-tavern.csv',
#  '139_club-royale.csv',
#  '13_al-chulas-american-grill.csv',
#  '140_coast-sushi-bar.csv',
#  '141_cocello.csv',
#  '145_como.csv',
#  '146_tutto-fresco.csv',
#  '148_costas.csv',
#  '149_cotes-du-rhone.csv',
#  '14_al-dente.csv',
#  '151_crofton-on-wells.csv',
#  '152_cru-cafe-and-wine-bar.csv',
#  '153_crust.csv',
#  '154_cuatro.csv',
#  '156_cuisines.csv',
#  '157_cullens-bar-and-grill.csv',
#  '158_custom-house-tavern.csv',
#  '159_cys-crab-house.csv',
#  '15_al-primo-canto.csv',
#  '160_cyranos-bistrot-and-wine-bar.csv',
#  '161_cyranos-farm-kitchen.csv',
#  '164_das.csv',
#  '166_del-toro.csv',
#  '167_de-la-costa.csv',
#  '168_deleece.csv',
#  '169_dellwood-pickle.csv',
#  '16_alberts-place.csv',
#  '170_demon-dogs.csv',
#  '171_dillmans.csv',
#  '173_dixie-kitchen-and-bait-shop.csv',
#  '176_dos-diablos.csv',
#  '177_double-li.csv',
#  '178_the-drawing-room.csv',
#  '179_duchamp.csv',
#  '17_aldinos.csv',
#  '180_d-vine-restaurant.csv',
#  '181_earth.csv',
#  '183_ed-debevics.csv',
#  '184_edwardos-natural-pizza-restaurant.csv',
#  '185_eivissa.csv',
#  '188_elis-the-place-for-steak.csv',
#  '189_embeya.csv',
#  '18_allens-new-american-cafe.csv',
#  '190_eno.csv',
#  '192_entre-nous-restaurant.csv',
#  '194_erwin.csv',
#  '195_espn-zone.csv',
#  '196_eve.csv',
#  '197_extra-virgin.csv',
#  '198_fahrenheit.csv',
#  '1_33-club.csv',
#  '200_famous-daves.csv',
#  '201_fattoush-restaurant.csv',
#  '202_feast.csv',
#  '203_fianco.csv',
#  '204_fiddlehead-cafe.csv',
#  '206_flo.csv',
#  '207_fiorentinos-cucina-italiana.csv',
#  '208_fitzers.csv',
#  '20_ambria.csv',
#  '211_flight-1551.csv',
#  '212_follia.csv',
#  '214_francescas-pizzeria-napoletana.csv',
#  '215_franks-n-dawgs.csv',
#  '216_freddys-ribhouse.csv',
#  '21_american-junkie.csv',
#  '221_garden-buffet.csv',
#  '222_gaylord-india-restaurant.csv',
#  '223_gennaros-restaurant.csv',
#  '224_gandhi-india-restaurant.csv',
#  '229_glory.csv',
#  '22_anderssons-kitchen-and-bakery.csv',
#  '230_grace.csv',
#  '231_grace-o-malleys.csv',
#  '232_graham-elliot.csv',
#  '233_grahamwich.csv',
#  '234_graze.csv',
#  '235_great-lake.csv',
#  '236_great-lake.csv',
#  '237_green-dolphin-street.csv',
#  '23_ani.csv',
#  '240_the-grotto-on-state.csv',
#  '241_hacienda-tecalitlan-restaurant.csv',
#  '242_hai-yen.csv',
#  '245_hatsuhana-sushi-restaurant.csv',
#  '246_henri.csv',
#  '247_hillarys-urban-eatery.csv',
#  '249_hong-min-restaurant.csv',
#  '24_ann-sathers.csv',
#  '250_hop-haus.csv',
#  '251_hot-dougs.csv',
#  '252_the-hot-spot.csv',
#  '256_hudson-club.csv',
#  '258_icream.csv',
#  '259_il-mulino.csv',
#  '25_arami.csv',
#  '260_in-fine-spirits-lounge.csv',
#  '262_indian-garden.csv',
#  '263_ing-restaurant.csv',
#  '266_itto-sushi.csv',
#  '267_ixcapuzalco.csv',
#  '269_jaipur-palace.csv',
#  '26_arco-de-cuchilleros.csv',
#  '270_jam.csv',
#  '271_japonais.csv',
#  '272_japonais-by-morimoto.csv',
#  '274_joes-be-bop-cafe.csv',
#  '275_joes-crab-shack.csv',
#  '276_joey-buonas-pizzareria.csv',
#  '277_john-barleycorn.csv',
#  '278_johnny-o-hagans.csv',
#  '279_johnny-rockets.csv',
#  '27_aria.csv',
#  '280_johns-place.csv',
#  '284_kabocha-japanese-brasserie.csv',
#  '285_kamehachi.csv',
#  '286_kan-zaman.csv',
#  '288_karyns-cooked.csv',
#  '289_kaze-sushi.csv',
#  '28_army-and-lous.csv',
#  '290_keefers.csv',
#  '291_kevin.csv',
#  '292_kith-and-kin.csv',
#  '293_kitschn-river-north.csv',
#  '294_klay-oven.csv',
#  '299_l2o.csv',
#  '29_arturo-express.csv',
#  '2_42-grams.csv',
#  '300_la-bocca-della-verita.csv',
#  '301_la-canasta.csv',
#  '303_la-rosetta.csv',
#  '304_la-salumeria-del-merlo.csv',
#  '306_la-strada-ristorante.csv',
#  '307_la-tache.csv',
#  '309_lalos-mexican-restaurant.csv',
#  '30_atlantique.csv',
#  '312_las-tablas.csv',
#  '314_le-lan.csv',
#  '315_le-passage.csv',
#  '318_leos-lunchroom.csv',
#  '319_leopold.csv',
#  '31_il-fiasco.csv',
#  '321_lexis.csv',
#  '323_little-bucharest.csv',
#  '326_luna.csv',
#  '327_macello.csv',
#  '32_august-moon.csv',
#  '331_mado.csv',
#  '334_maison-brasserie.csv',
#  '335_mambo-grill.csv',
#  '336_marche.csv',
#  '337_marigold.csv',
#  '338_marysol.csv',
#  '339_mas.csv',
#  '343_menagerie.csv',
#  '344_meritage-cafe-and-wine-bar.csv',
#  '345_meztiso-latin-bistro-and-wine-bar.csv',
#  '34_avenue-m.csv',
#  '359_mortons-the-steakhouse.csv',
#  '35_avenues-at-the-peninsula-chicago.csv',
#  '361_moto.csv',
#  '362_n9ne-steakhouse.csv',
#  '365_narcisse.csv',
#  '366_nazarlik.csv',
#  '367_nella-pizzeria-napoletana.csv',
#  '369_nicks-fishmarket-and-grill.csv',
#  '36_azzurra-enotavola.csv',
#  '370_nicks-fishmarket.csv',
#  '372_nomi.csv',
#  '373_nonno-pinos.csv',
#  '376_ofame.csv',
#  '377_ofame.csv',
#  '378_ohba.csv',
#  '380_old-town-brasserie.csv',
#  '381_ole-ole.csv',
#  '382_olive-branch.csv',
#  '384_one-sixtyblue.csv',
#  '386_oon.csv',
#  '387_opera.csv',
#  '38_ballo.csv',
#  '391_la-madia.csv',
#  '392_otom.csv',
#  '393_the-outpost.csv',
#  '395_the-palm.csv',
#  '397_pane-caldo.csv',
#  '398_papa-milano.csv',
#  '3_a-la-turka-turkish-kitchen.csv',
#  '400_papagus-greek-taverna.csv',
#  '401_pappadeaux.csv',
#  '402_paris-club.csv',
#  '403_park-avenue-cafe.csv',
#  '408_penang.csv',
#  '410_perennial.csv',
#  '411_perennial-virant.csv',
#  '412_phil-and-lous.csv',
#  '413_piazza-m.csv',
#  '414_pierogi-factory.csv',
#  '416_pili-pili.csv',
#  '419_platiyo.csv',
#  '41_bangkok-thai-cuisine.csv',
#  '420_pluton.csv',
#  '421_polak-eatery.csv',
#  '422_pork-shoppe.csv',
#  '423_porters-steakhouse.csv',
#  '424_powerhouse.csv',
#  '425_prairie-fire.csv',
#  '426_printers-row.csv',
#  '428_province.csv',
#  '42_barcellos.csv',
#  '432_real-tenochtitlan.csv',
#  '433_red-light.csv',
#  '434_red-lion-pub.csv',
#  '436_republic-pan-asian-restaurant-and-lounge.csv',
#  '438_rhapsody.csv',
#  '439_ria.csv',
#  '43_villa-d-oro.csv',
#  '440_rinconcito-sudamericano.csv',
#  '441_rioja.csv',
#  '442_ripasso.csv',
#  '443_ristorante-we.csv',
#  '444_riva.csv',
#  '446_rockstar-dogs.csv',
#  '447_rose-angelis.csv',
#  '449_rosebud-trattoria.csv',
#  '44_the-bedford.csv',
#  '451_rumba.csv',
#  '452_rural-society.csv',
#  '453_rushmore.csv',
#  '454_rustic-house.csv',
#  '456_saiko.csv',
#  '457_sal-and-carvao-churrascaria.csv',
#  '458_the-saloon-steakhouse.csv',
#  '459_salpicon.csv',
#  '45_bella-rosa-ristorante-and-galleria.csv',
#  '460_saltaus.csv',
#  '461_salud-tequila-lounge.csv',
#  '462_sapore-di-napoli.csv',
#  '464_scoozi.csv',
#  '465_scylla.csv',
#  '466_seasons.csv',
#  '467_seattles-best-coffee.csv',
#  '469_settimana-cafe.csv',
#  '46_bella-vista.csv',
#  '474_shochu.csv',
#  '478_socca.csv',
#  '479_souk.csv',
#  '47_belly-shack.csv',
#  '480_soul.csv',
#  '482_spring.csv',
#  '483_spruce.csv',
#  '484_square-kitchen.csv',
#  '485_starfish.csv',
#  '487_stefanis.csv',
#  '488_stone-lotus.csv',
#  '489_storefront-company.csv',
#  '48_ben-pao.csv',
#  '490_strega-nona.csv',
#  '491_sugar-and-browns.csv',
#  '492_sura-thai-bistro.csv',
#  '493_sushi-wabi.csv',
#  '494_sushi-x.csv',
#  '495_sushisamba-rio.csv',
#  '498_sweets-and-savories.csv',
#  '499_szechwan-east.csv',
#  '49_berrista-coffee.csv',
#  '4_a-mano.csv',
#  '500_takashi.csv',
#  '501_tallulah.csv',
#  '502_the-tasting-room.csv',
#  '504_tavernita.csv',
#  '507_telegraph.csv',
#  '508_tepatulco.csv',
#  '50_bertuccis-corner.csv',
#  '513_timo.csv',
#  '515_tizi-melloul.csv',
#  '516_tokyo-21.csv',
#  '520_trader-vics.csv',
#  '525_tsuki-japanese-restaurant-and-lounge.csv',
#  '529_urban-union.csv',
#  '52_bice-ristorante.csv',
#  '530_urbanbelly.csv',
#  '532_veerasway.csv',
#  '534_via-veneto.csv',
#  '535_via-ventuno.csv',
#  '537_vongs-thai-kitchen.csv',
#  '539_wave.csv',
#  '53_biggs-steakhouse-seafood-and-wine-cellar.csv',
#  '540_weber-grill-restaurant.csv',
#  '541_west-town-tavern.csv',
#  '542_winstons-market.csv',
#  '546_xel-ha.csv',
#  '550_zapatista.csv',
#  '553_zed451.csv',
#  '554_zest.csv',
#  '558_zoom-kitchen.csv',
#  '55_bin-36.csv',
#  '56_bin-wine-cafe.csv',
#  '57_bistro-110.csv',
#  '58_bistro-dre.csv',
#  '59_bistro-750.csv',
#  '61_bistro-pacific.csv',
#  '62_bistrot-margot.csv',
#  '63_bistrot-zinc.csv',
#  '64_grizzlys-lodge.csv',
#  '65_blu-coral.csv',
#  '66_blue-door-farm-stand.csv',
#  '68_blue-ocean.csv',
#  '69_bluepoint-oyster-bar.csv',
#  '6_abbey-pub.csv',
#  '70_blue-water-grill.csv',
#  '71_the-bluebird.csv',
#  '72_bob-chinns-crabhouse-chicago.csv',
#  '73_bobtail-ice-cream-company.csv',
#  '74_bombay-spice-grill-and-wine.csv',
#  '75_boston-blackies.csv',
#  '76_the-brass-monkey.csv',
#  '77_brasserie-jo.csv',
#  '78_brasserie-ruhlmann.csv',
#  '79_bravo-tapas-and-lounge.csv',
#  '7_abril-mexican-restaurant-logan-square.csv',
#  '80_brazzaz.csv',
#  '81_bretts-cafe-americain.csv',
#  '83_brio.csv',
#  '84_brother-jimmys.csv',
#  '85_browntrout.csv',
#  '86_buca-di-beppo.csv',
#  '87_bucks-chicken-and-biscuits.csv',
#  '88_buongiorno-cafe.csv',
#  '89_the-burger-philosophy.csv',
#  '90_butter.csv',
#  '91_butter.csv',
#  '92_butterfield-8.csv',
#  '93_byrons-hot-dogs.csv',
#  '94_c-house.csv',
#  '96_cafe-apollo.csv',
#  '97_cafe-bernard.csv',
#  '98_cafe-bionda.csv',
#  '99_cafe-bolero.csv',
#  '9_adesso.csv']

# %%
reviewfiles = [f for f in listdir('../Gayot_copy/') if '_review.csv' in f]

# %%
reviewfiles
# Out:
# ['0_2-sparrows_review.csv',
#  '100_coq-d-or-restaurant-and-lounge_review.csv',
#  '101_cafe-laguardia_review.csv',
#  '103_cafe-luciano_review.csv',
#  '104_cafe-matou_review.csv',
#  '105_cafe-chien_review.csv',
#  '106_cafe-selmarie_review.csv',
#  '107_caffe-baci_review.csv',
#  '10_adobo-grill_review.csv',
#  '110_cannellas-on-grand_review.csv',
#  '113_cantina-1910_review.csv',
#  '114_calo-ristorante_review.csv',
#  '116_carmichaels-chicago-steakhouse_review.csv',
#  '117_carriage-house_review.csv',
#  '118_centro_review.csv',
#  '119_cereality-cereal-bar-and-cafe_review.csv',
#  '11_aigre-doux_review.csv',
#  '120_ceres-table_review.csv',
#  '121_cerise_review.csv',
#  '122_chalkboard_review.csv',
#  '123_charlies-ale-house_review.csv',
#  '124_charlies-on-leavitt_review.csv',
#  '125_charlie-trotters_review.csv',
#  '126_chicago-flat-sammies_review.csv',
#  '127_chickpea_review.csv',
#  '128_chilapan_review.csv',
#  '129_chilpancingo_review.csv',
#  '12_aja_review.csv',
#  '130_china-grill_review.csv',
#  '131_chizakaya-japanese-pub_review.csv',
#  '133_cibo-matto_review.csv',
#  '134_cicchetti_review.csv',
#  '135_city-tavern_review.csv',
#  '137_nouveau-tavern_review.csv',
#  '139_club-royale_review.csv',
#  '13_al-chulas-american-grill_review.csv',
#  '140_coast-sushi-bar_review.csv',
#  '141_cocello_review.csv',
#  '145_como_review.csv',
#  '148_costas_review.csv',
#  '149_cotes-du-rhone_review.csv',
#  '14_al-dente_review.csv',
#  '151_crofton-on-wells_review.csv',
#  '152_cru-cafe-and-wine-bar_review.csv',
#  '153_crust_review.csv',
#  '154_cuatro_review.csv',
#  '156_cuisines_review.csv',
#  '157_cullens-bar-and-grill_review.csv',
#  '158_custom-house-tavern_review.csv',
#  '159_cys-crab-house_review.csv',
#  '15_al-primo-canto_review.csv',
#  '160_cyranos-bistrot-and-wine-bar_review.csv',
#  '161_cyranos-farm-kitchen_review.csv',
#  '164_das_review.csv',
#  '166_del-toro_review.csv',
#  '167_de-la-costa_review.csv',
#  '168_deleece_review.csv',
#  '169_dellwood-pickle_review.csv',
#  '170_demon-dogs_review.csv',
#  '171_dillmans_review.csv',
#  '173_dixie-kitchen-and-bait-shop_review.csv',
#  '176_dos-diablos_review.csv',
#  '177_double-li_review.csv',
#  '178_the-drawing-room_review.csv',
#  '179_duchamp_review.csv',
#  '17_aldinos_review.csv',
#  '180_d-vine-restaurant_review.csv',
#  '181_earth_review.csv',
#  '183_ed-debevics_review.csv',
#  '184_edwardos-natural-pizza-restaurant_review.csv',
#  '185_eivissa_review.csv',
#  '188_elis-the-place-for-steak_review.csv',
#  '189_embeya_review.csv',
#  '18_allens-new-american-cafe_review.csv',
#  '190_eno_review.csv',
#  '192_entre-nous-restaurant_review.csv',
#  '194_erwin_review.csv',
#  '195_espn-zone_review.csv',
#  '196_eve_review.csv',
#  '197_extra-virgin_review.csv',
#  '198_fahrenheit_review.csv',
#  '1_33-club_review.csv',
#  '200_famous-daves_review.csv',
#  '201_fattoush-restaurant_review.csv',
#  '202_feast_review.csv',
#  '203_fianco_review.csv',
#  '204_fiddlehead-cafe_review.csv',
#  '206_flo_review.csv',
#  '207_fiorentinos-cucina-italiana_review.csv',
#  '20_ambria_review.csv',
#  '211_flight-1551_review.csv',
#  '212_follia_review.csv',
#  '214_francescas-pizzeria-napoletana_review.csv',
#  '215_franks-n-dawgs_review.csv',
#  '216_freddys-ribhouse_review.csv',
#  '21_american-junkie_review.csv',
#  '221_garden-buffet_review.csv',
#  '223_gennaros-restaurant_review.csv',
#  '224_gandhi-india-restaurant_review.csv',
#  '229_glory_review.csv',
#  '22_anderssons-kitchen-and-bakery_review.csv',
#  '230_grace_review.csv',
#  '231_grace-o-malleys_review.csv',
#  '232_graham-elliot_review.csv',
#  '233_grahamwich_review.csv',
#  '234_graze_review.csv',
#  '235_great-lake_review.csv',
#  '237_green-dolphin-street_review.csv',
#  '23_ani_review.csv',
#  '240_the-grotto-on-state_review.csv',
#  '241_hacienda-tecalitlan-restaurant_review.csv',
#  '242_hai-yen_review.csv',
#  '246_henri_review.csv',
#  '247_hillarys-urban-eatery_review.csv',
#  '249_hong-min-restaurant_review.csv',
#  '24_ann-sathers_review.csv',
#  '250_hop-haus_review.csv',
#  '251_hot-dougs_review.csv',
#  '252_the-hot-spot_review.csv',
#  '256_hudson-club_review.csv',
#  '258_icream_review.csv',
#  '259_il-mulino_review.csv',
#  '25_arami_review.csv',
#  '260_in-fine-spirits-lounge_review.csv',
#  '262_indian-garden_review.csv',
#  '263_ing-restaurant_review.csv',
#  '266_itto-sushi_review.csv',
#  '267_ixcapuzalco_review.csv',
#  '269_jaipur-palace_review.csv',
#  '26_arco-de-cuchilleros_review.csv',
#  '270_jam_review.csv',
#  '271_japonais_review.csv',
#  '272_japonais-by-morimoto_review.csv',
#  '274_joes-be-bop-cafe_review.csv',
#  '275_joes-crab-shack_review.csv',
#  '276_joey-buonas-pizzareria_review.csv',
#  '277_john-barleycorn_review.csv',
#  '279_johnny-rockets_review.csv',
#  '27_aria_review.csv',
#  '280_johns-place_review.csv',
#  '284_kabocha-japanese-brasserie_review.csv',
#  '285_kamehachi_review.csv',
#  '286_kan-zaman_review.csv',
#  '288_karyns-cooked_review.csv',
#  '289_kaze-sushi_review.csv',
#  '28_army-and-lous_review.csv',
#  '290_keefers_review.csv',
#  '291_kevin_review.csv',
#  '292_kith-and-kin_review.csv',
#  '293_kitschn-river-north_review.csv',
#  '294_klay-oven_review.csv',
#  '296_kyoto-sushi-steak-seafood_review.csv',
#  '299_l2o_review.csv',
#  '29_arturo-express_review.csv',
#  '2_42-grams_review.csv',
#  '300_la-bocca-della-verita_review.csv',
#  '301_la-canasta_review.csv',
#  '302_la-donna-italian-cuisine_review.csv',
#  '303_la-rosetta_review.csv',
#  '304_la-salumeria-del-merlo_review.csv',
#  '305_la-strada-ristorante_review.csv',
#  '306_la-strada-ristorante_review.csv',
#  '307_la-tache_review.csv',
#  '308_la-vita-restaurant_review.csv',
#  '309_lalos-mexican-restaurant_review.csv',
#  '30_atlantique_review.csv',
#  '310_landmark-grill_review.csv',
#  '312_las-tablas_review.csv',
#  '314_le-lan_review.csv',
#  '315_le-passage_review.csv',
#  '318_leos-lunchroom_review.csv',
#  '319_leopold_review.csv',
#  '31_il-fiasco_review.csv',
#  '321_lexis_review.csv',
#  '322_lindo-mexico-restauant_review.csv',
#  '323_little-bucharest_review.csv',
#  '326_luna_review.csv',
#  '327_macello_review.csv',
#  '32_august-moon_review.csv',
#  '331_mado_review.csv',
#  '332_magnums-prime-steakhouse_review.csv',
#  '334_maison-brasserie_review.csv',
#  '335_mambo-grill_review.csv',
#  '336_marche_review.csv',
#  '337_marigold_review.csv',
#  '338_marysol_review.csv',
#  '339_mas_review.csv',
#  '343_menagerie_review.csv',
#  '344_meritage-cafe-and-wine-bar_review.csv',
#  '345_meztiso-latin-bistro-and-wine-bar_review.csv',
#  '346_mi-peru-restaurant-and-club_review.csv',
#  '34_avenue-m_review.csv',
#  '352_mk-restaurant_review.csv',
#  '358_moon-palace-restaurant_review.csv',
#  '359_mortons-the-steakhouse_review.csv',
#  '35_avenues-at-the-peninsula-chicago_review.csv',
#  '360_moti-mahal-indian-restaurant_review.csv',
#  '361_moto_review.csv',
#  '362_n9ne-steakhouse_review.csv',
#  '365_narcisse_review.csv',
#  '366_nazarlik_review.csv',
#  '367_nella-pizzeria-napoletana_review.csv',
#  '368_cafe-nhu-hoa_review.csv',
#  '369_nicks-fishmarket-and-grill_review.csv',
#  '36_azzurra-enotavola_review.csv',
#  '370_nicks-fishmarket_review.csv',
#  '371_rylons-smokehouse_review.csv',
#  '372_nomi_review.csv',
#  '373_nonno-pinos_review.csv',
#  '375_nuevo-leon-restaurant_review.csv',
#  '376_ofame_review.csv',
#  '377_ofame_review.csv',
#  '378_ohba_review.csv',
#  '380_old-town-brasserie_review.csv',
#  '381_ole-ole_review.csv',
#  '382_olive-branch_review.csv',
#  '384_one-sixtyblue_review.csv',
#  '386_oon_review.csv',
#  '387_opera_review.csv',
#  '388_leons-bar-b-q_review.csv',
#  '38_ballo_review.csv',
#  '391_la-madia_review.csv',
#  '392_otom_review.csv',
#  '393_the-outpost_review.csv',
#  '395_the-palm_review.csv',
#  '397_pane-caldo_review.csv',
#  '398_papa-milano_review.csv',
#  '399_papagus-greek-taverna_review.csv',
#  '3_a-la-turka-turkish-kitchen_review.csv',
#  '400_papagus-greek-taverna_review.csv',
#  '401_pappadeaux_review.csv',
#  '402_paris-club_review.csv',
#  '403_park-avenue-cafe_review.csv',
#  '404_the-parthenon_review.csv',
#  '408_penang_review.csv',
#  '410_perennial_review.csv',
#  '411_perennial-virant_review.csv',
#  '412_phil-and-lous_review.csv',
#  '413_piazza-m_review.csv',
#  '414_pierogi-factory_review.csv',
#  '416_pili-pili_review.csv',
#  '419_platiyo_review.csv',
#  '41_bangkok-thai-cuisine_review.csv',
#  '420_pluton_review.csv',
#  '421_polak-eatery_review.csv',
#  '422_pork-shoppe_review.csv',
#  '423_porters-steakhouse_review.csv',
#  '424_powerhouse_review.csv',
#  '425_prairie-fire_review.csv',
#  '426_printers-row_review.csv',
#  '427_province_review.csv',
#  '428_province_review.csv',
#  '42_barcellos_review.csv',
#  '432_real-tenochtitlan_review.csv',
#  '433_red-light_review.csv',
#  '434_red-lion-pub_review.csv',
#  '436_republic-pan-asian-restaurant-and-lounge_review.csv',
#  '438_rhapsody_review.csv',
#  '439_ria_review.csv',
#  '43_villa-d-oro_review.csv',
#  '440_rinconcito-sudamericano_review.csv',
#  '441_rioja_review.csv',
#  '442_ripasso_review.csv',
#  '443_ristorante-we_review.csv',
#  '444_riva_review.csv',
#  '446_rockstar-dogs_review.csv',
#  '447_rose-angelis_review.csv',
#  '449_rosebud-trattoria_review.csv',
#  '44_the-bedford_review.csv',
#  '451_rumba_review.csv',
#  '452_rural-society_review.csv',
#  '453_rushmore_review.csv',
#  '454_rustic-house_review.csv',
#  '455_sabor-a-cuba-restaurant_review.csv',
#  '456_saiko_review.csv',
#  '457_sal-and-carvao-churrascaria_review.csv',
#  '458_the-saloon-steakhouse_review.csv',
#  '459_salpicon_review.csv',
#  '45_bella-rosa-ristorante-and-galleria_review.csv',
#  '460_saltaus_review.csv',
#  '461_salud-tequila-lounge_review.csv',
#  '462_sapore-di-napoli_review.csv',
#  '464_scoozi_review.csv',
#  '465_scylla_review.csv',
#  '466_seasons_review.csv',
#  '467_seattles-best-coffee_review.csv',
#  '469_settimana-cafe_review.csv',
#  '46_bella-vista_review.csv',
#  '474_shochu_review.csv',
#  '478_socca_review.csv',
#  '479_souk_review.csv',
#  '47_belly-shack_review.csv',
#  '480_soul_review.csv',
#  '482_spring_review.csv',
#  '483_spruce_review.csv',
#  '484_square-kitchen_review.csv',
#  '485_starfish_review.csv',
#  '487_stefanis_review.csv',
#  '488_stone-lotus_review.csv',
#  '489_storefront-company_review.csv',
#  '48_ben-pao_review.csv',
#  '490_strega-nona_review.csv',
#  '491_sugar-and-browns_review.csv',
#  '492_sura-thai-bistro_review.csv',
#  '493_sushi-wabi_review.csv',
#  '494_sushi-x_review.csv',
#  '495_sushisamba-rio_review.csv',
#  '496_swank-frank-inc_review.csv',
#  '498_sweets-and-savories_review.csv',
#  '499_szechwan-east_review.csv',
#  '4_a-mano_review.csv',
#  '500_takashi_review.csv',
#  '501_tallulah_review.csv',
#  '502_the-tasting-room_review.csv',
#  '504_tavernita_review.csv',
#  '507_telegraph_review.csv',
#  '508_tepatulco_review.csv',
#  '509_thai-classic-restaurant_review.csv',
#  '511_thyme-restaurant_review.csv',
#  '513_timo_review.csv',
#  '515_tizi-melloul_review.csv',
#  '516_tokyo-21_review.csv',
#  '520_trader-vics_review.csv',
#  '522_treat-restaurant_review.csv',
#  '525_tsuki-japanese-restaurant-and-lounge_review.csv',
#  '526_tsunami-japanese-restaurant_review.csv',
#  '527_tuscany-restaurant_review.csv',
#  '529_urban-union_review.csv',
#  '52_bice-ristorante_review.csv',
#  '530_urbanbelly_review.csv',
#  '532_veerasway_review.csv',
#  '534_via-veneto_review.csv',
#  '535_via-ventuno_review.csv',
#  '537_vongs-thai-kitchen_review.csv',
#  '539_wave_review.csv',
#  '53_biggs-steakhouse-seafood-and-wine-cellar_review.csv',
#  '540_weber-grill-restaurant_review.csv',
#  '541_west-town-tavern_review.csv',
#  '542_winstons-market_review.csv',
#  '545_x-o-chicago_review.csv',
#  '546_xel-ha_review.csv',
#  '550_zapatista_review.csv',
#  '551_le-petit-paris_review.csv',
#  '552_zealous-restaurant_review.csv',
#  '553_zed451_review.csv',
#  '554_zest_review.csv',
#  '555_osteria-la-madia_review.csv',
#  '556_zk-food_review.csv',
#  '557_zocalo_review.csv',
#  '558_zoom-kitchen_review.csv',
#  '55_bin-36_review.csv',
#  '56_bin-wine-cafe_review.csv',
#  '57_bistro-110_review.csv',
#  '58_bistro-dre_review.csv',
#  '59_bistro-750_review.csv',
#  '61_bistro-pacific_review.csv',
#  '62_bistrot-margot_review.csv',
#  '63_bistrot-zinc_review.csv',
#  '65_blu-coral_review.csv',
#  '66_blue-door-farm-stand_review.csv',
#  '68_blue-ocean_review.csv',
#  '69_bluepoint-oyster-bar_review.csv',
#  '6_abbey-pub_review.csv',
#  '70_blue-water-grill_review.csv',
#  '71_the-bluebird_review.csv',
#  '72_bob-chinns-crabhouse-chicago_review.csv',
#  '73_bobtail-ice-cream-company_review.csv',
#  '74_bombay-spice-grill-and-wine_review.csv',
#  '75_boston-blackies_review.csv',
#  '76_the-brass-monkey_review.csv',
#  '77_brasserie-jo_review.csv',
#  '78_brasserie-ruhlmann_review.csv',
#  '79_bravo-tapas-and-lounge_review.csv',
#  '80_brazzaz_review.csv',
#  '81_bretts-cafe-americain_review.csv',
#  '83_brio_review.csv',
#  '84_brother-jimmys_review.csv',
#  '85_browntrout_review.csv',
#  '86_buca-di-beppo_review.csv',
#  '87_bucks-chicken-and-biscuits_review.csv',
#  '88_buongiorno-cafe_review.csv',
#  '89_the-burger-philosophy_review.csv',
#  '90_butter_review.csv',
#  '91_butter_review.csv',
#  '92_butterfield-8_review.csv',
#  '93_byrons-hot-dogs_review.csv',
#  '94_c-house_review.csv',
#  '96_cafe-apollo_review.csv',
#  '97_cafe-bernard_review.csv',
#  '98_cafe-bionda_review.csv',
#  '99_cafe-bolero_review.csv',
#  '9_adesso_review.csv']

# %%
import shutil
for file in infofiles:
    review_file = file[:-4]+'_review.csv'
    if review_file in reviewfiles:
        shutil.copy2('../Gayot_copy/'+review_file, './')
        print('want to copy '+'../Gayot_copy/'+file[:-4]+'_review.csv')
# Out:
# want to copy ../Gayot_copy/0_2-sparrows_review.csv
# want to copy ../Gayot_copy/100_coq-d-or-restaurant-and-lounge_review.csv
# want to copy ../Gayot_copy/101_cafe-laguardia_review.csv
# want to copy ../Gayot_copy/103_cafe-luciano_review.csv
# want to copy ../Gayot_copy/104_cafe-matou_review.csv
# want to copy ../Gayot_copy/105_cafe-chien_review.csv
# want to copy ../Gayot_copy/106_cafe-selmarie_review.csv
# want to copy ../Gayot_copy/107_caffe-baci_review.csv
# want to copy ../Gayot_copy/10_adobo-grill_review.csv
# want to copy ../Gayot_copy/110_cannellas-on-grand_review.csv
# want to copy ../Gayot_copy/113_cantina-1910_review.csv
# want to copy ../Gayot_copy/114_calo-ristorante_review.csv
# want to copy ../Gayot_copy/116_carmichaels-chicago-steakhouse_review.csv
# want to copy ../Gayot_copy/117_carriage-house_review.csv
# want to copy ../Gayot_copy/118_centro_review.csv
# want to copy ../Gayot_copy/119_cereality-cereal-bar-and-cafe_review.csv
# want to copy ../Gayot_copy/11_aigre-doux_review.csv
# want to copy ../Gayot_copy/120_ceres-table_review.csv
# want to copy ../Gayot_copy/121_cerise_review.csv
# want to copy ../Gayot_copy/122_chalkboard_review.csv
# want to copy ../Gayot_copy/123_charlies-ale-house_review.csv
# want to copy ../Gayot_copy/124_charlies-on-leavitt_review.csv
# want to copy ../Gayot_copy/125_charlie-trotters_review.csv
# want to copy ../Gayot_copy/126_chicago-flat-sammies_review.csv
# want to copy ../Gayot_copy/127_chickpea_review.csv
# want to copy ../Gayot_copy/128_chilapan_review.csv
# want to copy ../Gayot_copy/129_chilpancingo_review.csv
# want to copy ../Gayot_copy/12_aja_review.csv
# want to copy ../Gayot_copy/130_china-grill_review.csv
# want to copy ../Gayot_copy/131_chizakaya-japanese-pub_review.csv
# want to copy ../Gayot_copy/133_cibo-matto_review.csv
# want to copy ../Gayot_copy/134_cicchetti_review.csv
# want to copy ../Gayot_copy/135_city-tavern_review.csv
# want to copy ../Gayot_copy/137_nouveau-tavern_review.csv
# want to copy ../Gayot_copy/139_club-royale_review.csv
# want to copy ../Gayot_copy/13_al-chulas-american-grill_review.csv
# want to copy ../Gayot_copy/140_coast-sushi-bar_review.csv
# want to copy ../Gayot_copy/141_cocello_review.csv
# want to copy ../Gayot_copy/145_como_review.csv
# want to copy ../Gayot_copy/148_costas_review.csv
# want to copy ../Gayot_copy/149_cotes-du-rhone_review.csv
# want to copy ../Gayot_copy/14_al-dente_review.csv
# want to copy ../Gayot_copy/151_crofton-on-wells_review.csv
# want to copy ../Gayot_copy/152_cru-cafe-and-wine-bar_review.csv
# want to copy ../Gayot_copy/153_crust_review.csv
# want to copy ../Gayot_copy/154_cuatro_review.csv
# want to copy ../Gayot_copy/156_cuisines_review.csv
# want to copy ../Gayot_copy/157_cullens-bar-and-grill_review.csv
# want to copy ../Gayot_copy/158_custom-house-tavern_review.csv
# want to copy ../Gayot_copy/159_cys-crab-house_review.csv
# want to copy ../Gayot_copy/15_al-primo-canto_review.csv
# want to copy ../Gayot_copy/160_cyranos-bistrot-and-wine-bar_review.csv
# want to copy ../Gayot_copy/161_cyranos-farm-kitchen_review.csv
# want to copy ../Gayot_copy/164_das_review.csv
# want to copy ../Gayot_copy/166_del-toro_review.csv
# want to copy ../Gayot_copy/167_de-la-costa_review.csv
# want to copy ../Gayot_copy/168_deleece_review.csv
# want to copy ../Gayot_copy/169_dellwood-pickle_review.csv
# want to copy ../Gayot_copy/170_demon-dogs_review.csv
# want to copy ../Gayot_copy/171_dillmans_review.csv
# want to copy ../Gayot_copy/173_dixie-kitchen-and-bait-shop_review.csv
# want to copy ../Gayot_copy/176_dos-diablos_review.csv
# want to copy ../Gayot_copy/177_double-li_review.csv
# want to copy ../Gayot_copy/178_the-drawing-room_review.csv
# want to copy ../Gayot_copy/179_duchamp_review.csv
# want to copy ../Gayot_copy/17_aldinos_review.csv
# want to copy ../Gayot_copy/180_d-vine-restaurant_review.csv
# want to copy ../Gayot_copy/181_earth_review.csv
# want to copy ../Gayot_copy/183_ed-debevics_review.csv
# want to copy ../Gayot_copy/184_edwardos-natural-pizza-restaurant_review.csv
# want to copy ../Gayot_copy/185_eivissa_review.csv
# want to copy ../Gayot_copy/188_elis-the-place-for-steak_review.csv
# want to copy ../Gayot_copy/189_embeya_review.csv
# want to copy ../Gayot_copy/18_allens-new-american-cafe_review.csv
# want to copy ../Gayot_copy/190_eno_review.csv
# want to copy ../Gayot_copy/192_entre-nous-restaurant_review.csv
# want to copy ../Gayot_copy/194_erwin_review.csv
# want to copy ../Gayot_copy/195_espn-zone_review.csv
# want to copy ../Gayot_copy/196_eve_review.csv
# want to copy ../Gayot_copy/197_extra-virgin_review.csv
# want to copy ../Gayot_copy/198_fahrenheit_review.csv
# want to copy ../Gayot_copy/1_33-club_review.csv
# want to copy ../Gayot_copy/200_famous-daves_review.csv
# want to copy ../Gayot_copy/201_fattoush-restaurant_review.csv
# want to copy ../Gayot_copy/202_feast_review.csv
# want to copy ../Gayot_copy/203_fianco_review.csv
# want to copy ../Gayot_copy/204_fiddlehead-cafe_review.csv
# want to copy ../Gayot_copy/206_flo_review.csv
# want to copy ../Gayot_copy/207_fiorentinos-cucina-italiana_review.csv
# want to copy ../Gayot_copy/20_ambria_review.csv
# want to copy ../Gayot_copy/211_flight-1551_review.csv
# want to copy ../Gayot_copy/212_follia_review.csv
# want to copy ../Gayot_copy/214_francescas-pizzeria-napoletana_review.csv
# want to copy ../Gayot_copy/215_franks-n-dawgs_review.csv
# want to copy ../Gayot_copy/216_freddys-ribhouse_review.csv
# want to copy ../Gayot_copy/21_american-junkie_review.csv
# want to copy ../Gayot_copy/221_garden-buffet_review.csv
# want to copy ../Gayot_copy/223_gennaros-restaurant_review.csv
# want to copy ../Gayot_copy/224_gandhi-india-restaurant_review.csv
# want to copy ../Gayot_copy/229_glory_review.csv
# want to copy ../Gayot_copy/22_anderssons-kitchen-and-bakery_review.csv
# want to copy ../Gayot_copy/230_grace_review.csv
# want to copy ../Gayot_copy/231_grace-o-malleys_review.csv
# want to copy ../Gayot_copy/232_graham-elliot_review.csv
# want to copy ../Gayot_copy/233_grahamwich_review.csv
# want to copy ../Gayot_copy/234_graze_review.csv
# want to copy ../Gayot_copy/235_great-lake_review.csv
# want to copy ../Gayot_copy/237_green-dolphin-street_review.csv
# want to copy ../Gayot_copy/23_ani_review.csv
# want to copy ../Gayot_copy/240_the-grotto-on-state_review.csv
# want to copy ../Gayot_copy/241_hacienda-tecalitlan-restaurant_review.csv
# want to copy ../Gayot_copy/242_hai-yen_review.csv
# want to copy ../Gayot_copy/246_henri_review.csv
# want to copy ../Gayot_copy/247_hillarys-urban-eatery_review.csv
# want to copy ../Gayot_copy/249_hong-min-restaurant_review.csv
# want to copy ../Gayot_copy/24_ann-sathers_review.csv
# want to copy ../Gayot_copy/250_hop-haus_review.csv
# want to copy ../Gayot_copy/251_hot-dougs_review.csv
# want to copy ../Gayot_copy/252_the-hot-spot_review.csv
# want to copy ../Gayot_copy/256_hudson-club_review.csv
# want to copy ../Gayot_copy/258_icream_review.csv
# want to copy ../Gayot_copy/259_il-mulino_review.csv
# want to copy ../Gayot_copy/25_arami_review.csv
# want to copy ../Gayot_copy/260_in-fine-spirits-lounge_review.csv
# want to copy ../Gayot_copy/262_indian-garden_review.csv
# want to copy ../Gayot_copy/263_ing-restaurant_review.csv
# want to copy ../Gayot_copy/266_itto-sushi_review.csv
# want to copy ../Gayot_copy/267_ixcapuzalco_review.csv
# want to copy ../Gayot_copy/269_jaipur-palace_review.csv
# want to copy ../Gayot_copy/26_arco-de-cuchilleros_review.csv
# want to copy ../Gayot_copy/270_jam_review.csv
# want to copy ../Gayot_copy/271_japonais_review.csv
# want to copy ../Gayot_copy/272_japonais-by-morimoto_review.csv
# want to copy ../Gayot_copy/274_joes-be-bop-cafe_review.csv
# want to copy ../Gayot_copy/275_joes-crab-shack_review.csv
# want to copy ../Gayot_copy/276_joey-buonas-pizzareria_review.csv
# want to copy ../Gayot_copy/277_john-barleycorn_review.csv
# want to copy ../Gayot_copy/279_johnny-rockets_review.csv
# want to copy ../Gayot_copy/27_aria_review.csv
# want to copy ../Gayot_copy/280_johns-place_review.csv
# want to copy ../Gayot_copy/284_kabocha-japanese-brasserie_review.csv
# want to copy ../Gayot_copy/285_kamehachi_review.csv
# want to copy ../Gayot_copy/286_kan-zaman_review.csv
# want to copy ../Gayot_copy/288_karyns-cooked_review.csv
# want to copy ../Gayot_copy/289_kaze-sushi_review.csv
# want to copy ../Gayot_copy/28_army-and-lous_review.csv
# want to copy ../Gayot_copy/290_keefers_review.csv
# want to copy ../Gayot_copy/291_kevin_review.csv
# want to copy ../Gayot_copy/292_kith-and-kin_review.csv
# want to copy ../Gayot_copy/293_kitschn-river-north_review.csv
# want to copy ../Gayot_copy/294_klay-oven_review.csv
# want to copy ../Gayot_copy/299_l2o_review.csv
# want to copy ../Gayot_copy/29_arturo-express_review.csv
# want to copy ../Gayot_copy/2_42-grams_review.csv
# want to copy ../Gayot_copy/300_la-bocca-della-verita_review.csv
# want to copy ../Gayot_copy/301_la-canasta_review.csv
# want to copy ../Gayot_copy/303_la-rosetta_review.csv
# want to copy ../Gayot_copy/304_la-salumeria-del-merlo_review.csv
# want to copy ../Gayot_copy/306_la-strada-ristorante_review.csv
# want to copy ../Gayot_copy/307_la-tache_review.csv
# want to copy ../Gayot_copy/309_lalos-mexican-restaurant_review.csv
# want to copy ../Gayot_copy/30_atlantique_review.csv
# want to copy ../Gayot_copy/312_las-tablas_review.csv
# want to copy ../Gayot_copy/314_le-lan_review.csv
# want to copy ../Gayot_copy/315_le-passage_review.csv
# want to copy ../Gayot_copy/318_leos-lunchroom_review.csv
# want to copy ../Gayot_copy/319_leopold_review.csv
# want to copy ../Gayot_copy/31_il-fiasco_review.csv
# want to copy ../Gayot_copy/321_lexis_review.csv
# want to copy ../Gayot_copy/323_little-bucharest_review.csv
# want to copy ../Gayot_copy/326_luna_review.csv
# want to copy ../Gayot_copy/327_macello_review.csv
# want to copy ../Gayot_copy/32_august-moon_review.csv
# want to copy ../Gayot_copy/331_mado_review.csv
# want to copy ../Gayot_copy/334_maison-brasserie_review.csv
# want to copy ../Gayot_copy/335_mambo-grill_review.csv
# want to copy ../Gayot_copy/336_marche_review.csv
# want to copy ../Gayot_copy/337_marigold_review.csv
# want to copy ../Gayot_copy/338_marysol_review.csv
# want to copy ../Gayot_copy/339_mas_review.csv
# want to copy ../Gayot_copy/343_menagerie_review.csv
# want to copy ../Gayot_copy/344_meritage-cafe-and-wine-bar_review.csv
# want to copy ../Gayot_copy/345_meztiso-latin-bistro-and-wine-bar_review.csv
# want to copy ../Gayot_copy/34_avenue-m_review.csv
# want to copy ../Gayot_copy/359_mortons-the-steakhouse_review.csv
# want to copy ../Gayot_copy/35_avenues-at-the-peninsula-chicago_review.csv
# want to copy ../Gayot_copy/361_moto_review.csv
# want to copy ../Gayot_copy/362_n9ne-steakhouse_review.csv
# want to copy ../Gayot_copy/365_narcisse_review.csv
# want to copy ../Gayot_copy/366_nazarlik_review.csv
# want to copy ../Gayot_copy/367_nella-pizzeria-napoletana_review.csv
# want to copy ../Gayot_copy/369_nicks-fishmarket-and-grill_review.csv
# want to copy ../Gayot_copy/36_azzurra-enotavola_review.csv
# want to copy ../Gayot_copy/370_nicks-fishmarket_review.csv
# want to copy ../Gayot_copy/372_nomi_review.csv
# want to copy ../Gayot_copy/373_nonno-pinos_review.csv
# want to copy ../Gayot_copy/376_ofame_review.csv
# want to copy ../Gayot_copy/377_ofame_review.csv
# want to copy ../Gayot_copy/378_ohba_review.csv
# want to copy ../Gayot_copy/380_old-town-brasserie_review.csv
# want to copy ../Gayot_copy/381_ole-ole_review.csv
# want to copy ../Gayot_copy/382_olive-branch_review.csv
# want to copy ../Gayot_copy/384_one-sixtyblue_review.csv
# want to copy ../Gayot_copy/386_oon_review.csv
# want to copy ../Gayot_copy/387_opera_review.csv
# want to copy ../Gayot_copy/38_ballo_review.csv
# want to copy ../Gayot_copy/391_la-madia_review.csv
# want to copy ../Gayot_copy/392_otom_review.csv
# want to copy ../Gayot_copy/393_the-outpost_review.csv
# want to copy ../Gayot_copy/395_the-palm_review.csv
# want to copy ../Gayot_copy/397_pane-caldo_review.csv
# want to copy ../Gayot_copy/398_papa-milano_review.csv
# want to copy ../Gayot_copy/3_a-la-turka-turkish-kitchen_review.csv
# want to copy ../Gayot_copy/400_papagus-greek-taverna_review.csv
# want to copy ../Gayot_copy/401_pappadeaux_review.csv
# want to copy ../Gayot_copy/402_paris-club_review.csv
# want to copy ../Gayot_copy/403_park-avenue-cafe_review.csv
# want to copy ../Gayot_copy/408_penang_review.csv
# want to copy ../Gayot_copy/410_perennial_review.csv
# want to copy ../Gayot_copy/411_perennial-virant_review.csv
# want to copy ../Gayot_copy/412_phil-and-lous_review.csv
# want to copy ../Gayot_copy/413_piazza-m_review.csv
# want to copy ../Gayot_copy/414_pierogi-factory_review.csv
# want to copy ../Gayot_copy/416_pili-pili_review.csv
# want to copy ../Gayot_copy/419_platiyo_review.csv
# want to copy ../Gayot_copy/41_bangkok-thai-cuisine_review.csv
# want to copy ../Gayot_copy/420_pluton_review.csv
# want to copy ../Gayot_copy/421_polak-eatery_review.csv
# want to copy ../Gayot_copy/422_pork-shoppe_review.csv
# want to copy ../Gayot_copy/423_porters-steakhouse_review.csv
# want to copy ../Gayot_copy/424_powerhouse_review.csv
# want to copy ../Gayot_copy/425_prairie-fire_review.csv
# want to copy ../Gayot_copy/426_printers-row_review.csv
# want to copy ../Gayot_copy/428_province_review.csv
# want to copy ../Gayot_copy/42_barcellos_review.csv
# want to copy ../Gayot_copy/432_real-tenochtitlan_review.csv
# want to copy ../Gayot_copy/433_red-light_review.csv
# want to copy ../Gayot_copy/434_red-lion-pub_review.csv
# want to copy ../Gayot_copy/436_republic-pan-asian-restaurant-and-lounge_review.csv
# want to copy ../Gayot_copy/438_rhapsody_review.csv
# want to copy ../Gayot_copy/439_ria_review.csv
# want to copy ../Gayot_copy/43_villa-d-oro_review.csv
# want to copy ../Gayot_copy/440_rinconcito-sudamericano_review.csv
# want to copy ../Gayot_copy/441_rioja_review.csv
# want to copy ../Gayot_copy/442_ripasso_review.csv
# want to copy ../Gayot_copy/443_ristorante-we_review.csv
# want to copy ../Gayot_copy/444_riva_review.csv
# want to copy ../Gayot_copy/446_rockstar-dogs_review.csv
# want to copy ../Gayot_copy/447_rose-angelis_review.csv
# want to copy ../Gayot_copy/449_rosebud-trattoria_review.csv
# want to copy ../Gayot_copy/44_the-bedford_review.csv
# want to copy ../Gayot_copy/451_rumba_review.csv
# want to copy ../Gayot_copy/452_rural-society_review.csv
# want to copy ../Gayot_copy/453_rushmore_review.csv
# want to copy ../Gayot_copy/454_rustic-house_review.csv
# want to copy ../Gayot_copy/456_saiko_review.csv
# want to copy ../Gayot_copy/457_sal-and-carvao-churrascaria_review.csv
# want to copy ../Gayot_copy/458_the-saloon-steakhouse_review.csv
# want to copy ../Gayot_copy/459_salpicon_review.csv
# want to copy ../Gayot_copy/45_bella-rosa-ristorante-and-galleria_review.csv
# want to copy ../Gayot_copy/460_saltaus_review.csv
# want to copy ../Gayot_copy/461_salud-tequila-lounge_review.csv
# want to copy ../Gayot_copy/462_sapore-di-napoli_review.csv
# want to copy ../Gayot_copy/464_scoozi_review.csv
# want to copy ../Gayot_copy/465_scylla_review.csv
# want to copy ../Gayot_copy/466_seasons_review.csv
# want to copy ../Gayot_copy/467_seattles-best-coffee_review.csv
# want to copy ../Gayot_copy/469_settimana-cafe_review.csv
# want to copy ../Gayot_copy/46_bella-vista_review.csv
# want to copy ../Gayot_copy/474_shochu_review.csv
# want to copy ../Gayot_copy/478_socca_review.csv
# want to copy ../Gayot_copy/479_souk_review.csv
# want to copy ../Gayot_copy/47_belly-shack_review.csv
# want to copy ../Gayot_copy/480_soul_review.csv
# want to copy ../Gayot_copy/482_spring_review.csv
# want to copy ../Gayot_copy/483_spruce_review.csv
# want to copy ../Gayot_copy/484_square-kitchen_review.csv
# want to copy ../Gayot_copy/485_starfish_review.csv
# want to copy ../Gayot_copy/487_stefanis_review.csv
# want to copy ../Gayot_copy/488_stone-lotus_review.csv
# want to copy ../Gayot_copy/489_storefront-company_review.csv
# want to copy ../Gayot_copy/48_ben-pao_review.csv
# want to copy ../Gayot_copy/490_strega-nona_review.csv
# want to copy ../Gayot_copy/491_sugar-and-browns_review.csv
# want to copy ../Gayot_copy/492_sura-thai-bistro_review.csv
# want to copy ../Gayot_copy/493_sushi-wabi_review.csv
# want to copy ../Gayot_copy/494_sushi-x_review.csv
# want to copy ../Gayot_copy/495_sushisamba-rio_review.csv
# want to copy ../Gayot_copy/498_sweets-and-savories_review.csv
# want to copy ../Gayot_copy/499_szechwan-east_review.csv
# want to copy ../Gayot_copy/4_a-mano_review.csv
# want to copy ../Gayot_copy/500_takashi_review.csv
# want to copy ../Gayot_copy/501_tallulah_review.csv
# want to copy ../Gayot_copy/502_the-tasting-room_review.csv
# want to copy ../Gayot_copy/504_tavernita_review.csv
# want to copy ../Gayot_copy/507_telegraph_review.csv
# want to copy ../Gayot_copy/508_tepatulco_review.csv
# want to copy ../Gayot_copy/513_timo_review.csv
# want to copy ../Gayot_copy/515_tizi-melloul_review.csv
# want to copy ../Gayot_copy/516_tokyo-21_review.csv
# want to copy ../Gayot_copy/520_trader-vics_review.csv
# want to copy ../Gayot_copy/525_tsuki-japanese-restaurant-and-lounge_review.csv
# want to copy ../Gayot_copy/529_urban-union_review.csv
# want to copy ../Gayot_copy/52_bice-ristorante_review.csv
# want to copy ../Gayot_copy/530_urbanbelly_review.csv
# want to copy ../Gayot_copy/532_veerasway_review.csv
# want to copy ../Gayot_copy/534_via-veneto_review.csv
# want to copy ../Gayot_copy/535_via-ventuno_review.csv
# want to copy ../Gayot_copy/537_vongs-thai-kitchen_review.csv
# want to copy ../Gayot_copy/539_wave_review.csv
# want to copy ../Gayot_copy/53_biggs-steakhouse-seafood-and-wine-cellar_review.csv
# want to copy ../Gayot_copy/540_weber-grill-restaurant_review.csv
# want to copy ../Gayot_copy/541_west-town-tavern_review.csv
# want to copy ../Gayot_copy/542_winstons-market_review.csv
# want to copy ../Gayot_copy/546_xel-ha_review.csv
# want to copy ../Gayot_copy/550_zapatista_review.csv
# want to copy ../Gayot_copy/553_zed451_review.csv
# want to copy ../Gayot_copy/554_zest_review.csv
# want to copy ../Gayot_copy/558_zoom-kitchen_review.csv
# want to copy ../Gayot_copy/55_bin-36_review.csv
# want to copy ../Gayot_copy/56_bin-wine-cafe_review.csv
# want to copy ../Gayot_copy/57_bistro-110_review.csv
# want to copy ../Gayot_copy/58_bistro-dre_review.csv
# want to copy ../Gayot_copy/59_bistro-750_review.csv
# want to copy ../Gayot_copy/61_bistro-pacific_review.csv
# want to copy ../Gayot_copy/62_bistrot-margot_review.csv
# want to copy ../Gayot_copy/63_bistrot-zinc_review.csv
# want to copy ../Gayot_copy/65_blu-coral_review.csv
# want to copy ../Gayot_copy/66_blue-door-farm-stand_review.csv
# want to copy ../Gayot_copy/68_blue-ocean_review.csv
# want to copy ../Gayot_copy/69_bluepoint-oyster-bar_review.csv
# want to copy ../Gayot_copy/6_abbey-pub_review.csv
# want to copy ../Gayot_copy/70_blue-water-grill_review.csv
# want to copy ../Gayot_copy/71_the-bluebird_review.csv
# want to copy ../Gayot_copy/72_bob-chinns-crabhouse-chicago_review.csv
# want to copy ../Gayot_copy/73_bobtail-ice-cream-company_review.csv
# want to copy ../Gayot_copy/74_bombay-spice-grill-and-wine_review.csv
# want to copy ../Gayot_copy/75_boston-blackies_review.csv
# want to copy ../Gayot_copy/76_the-brass-monkey_review.csv
# want to copy ../Gayot_copy/77_brasserie-jo_review.csv
# want to copy ../Gayot_copy/78_brasserie-ruhlmann_review.csv
# want to copy ../Gayot_copy/79_bravo-tapas-and-lounge_review.csv
# want to copy ../Gayot_copy/80_brazzaz_review.csv
# want to copy ../Gayot_copy/81_bretts-cafe-americain_review.csv
# want to copy ../Gayot_copy/83_brio_review.csv
# want to copy ../Gayot_copy/84_brother-jimmys_review.csv
# want to copy ../Gayot_copy/85_browntrout_review.csv
# want to copy ../Gayot_copy/86_buca-di-beppo_review.csv
# want to copy ../Gayot_copy/87_bucks-chicken-and-biscuits_review.csv
# want to copy ../Gayot_copy/88_buongiorno-cafe_review.csv
# want to copy ../Gayot_copy/89_the-burger-philosophy_review.csv
# want to copy ../Gayot_copy/90_butter_review.csv
# want to copy ../Gayot_copy/91_butter_review.csv
# want to copy ../Gayot_copy/92_butterfield-8_review.csv
# want to copy ../Gayot_copy/93_byrons-hot-dogs_review.csv
# want to copy ../Gayot_copy/94_c-house_review.csv
# want to copy ../Gayot_copy/96_cafe-apollo_review.csv
# want to copy ../Gayot_copy/97_cafe-bernard_review.csv
# want to copy ../Gayot_copy/98_cafe-bionda_review.csv
# want to copy ../Gayot_copy/99_cafe-bolero_review.csv
# want to copy ../Gayot_copy/9_adesso_review.csv
