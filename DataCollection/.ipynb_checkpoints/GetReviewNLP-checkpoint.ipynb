# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from datetime import timedelta

# %%
def GetSentiment(df=None, column=None, prefix=''):
    from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
    #from nltk.sentiment.vader import SentimentIntensityAnalyzer
    sia = SentimentIntensityAnalyzer()
    Sent = df[[column]].copy()
    Sent[prefix+'compound'] = Sent[column].apply(lambda x: sia.polarity_scores(x)['compound'])
    Sent[prefix+'neutral'] = Sent[column].apply(lambda x: sia.polarity_scores(x)['neu'])
    Sent[prefix+'positive'] = Sent[column].apply(lambda x: sia.polarity_scores(x)['pos'])
    Sent[prefix+'negative'] = Sent[column].apply(lambda x: sia.polarity_scores(x)['neg'])
    return Sent.iloc[:,1:]

# %%
def GetSubjectivity(df=None, column=None, prefix=''):
    from textblob import TextBlob
    Sub = df[[column]].copy()
    Sub[prefix+'subjectivity'] = Sub[column].apply(lambda x: TextBlob(x).sentiment.subjectivity )
    return Sub.iloc[:,1:]

# %%
def GetReviewFiles(path='./'):
    from os import listdir
    files = [f for f in listdir(path)]
    Reviewfiles = [f for f in files if '_review.csv' in f]
    return Reviewfiles

# %%
def GetReviewNLP(path='./'):
    reviewfiles = GetReviewFiles(path=path)
    for file in reviewfiles:
        print(path+file)
        df = pd.read_csv(path+file)
        if len(df.columns) == 3:  
            Sentiment = GetSentiment(df=df, column='text', prefix='')
            Subjectivity = GetSubjectivity(df=df, column='text', prefix='')
            df = df.join(Sentiment).join(Subjectivity)
            df.to_csv(path+file, index=False)

# %%
def GetReviewNLPforFile(file='./OpenRestaurants/1123_mindys-hot-chocolate-chicago-2_review.csv'):
    print(file)
    df = pd.read_csv(file)
    if len(df.columns) == 3:  
        Sentiment = GetSentiment(df=df, column='text', prefix='')
        Subjectivity = GetSubjectivity(df=df, column='text', prefix='')
        df = df.join(Sentiment).join(Subjectivity)
        df.to_csv(file, index=False)

# %%
GetReviewNLP(path='./Gayot/')
# Out:
# ./Gayot/0_2-sparrows_review.csv
# ./Gayot/100_coq-d-or-restaurant-and-lounge_review.csv
# ./Gayot/101_cafe-laguardia_review.csv
# ./Gayot/103_cafe-luciano_review.csv
# ./Gayot/104_cafe-matou_review.csv
# ./Gayot/105_cafe-chien_review.csv
# ./Gayot/106_cafe-selmarie_review.csv
# ./Gayot/107_caffe-baci_review.csv
# ./Gayot/108_caliterra_review.csv
# ./Gayot/109_cambridge-house-ltd_review.csv
# ./Gayot/10_adobo-grill_review.csv
# ./Gayot/110_cannellas-on-grand_review.csv
# ./Gayot/113_cantina-1910_review.csv
# ./Gayot/114_calo-ristorante_review.csv
# ./Gayot/115_filippos-ristorante_review.csv
# ./Gayot/116_carmichaels-chicago-steakhouse_review.csv
# ./Gayot/117_carriage-house_review.csv
# ./Gayot/118_centro_review.csv
# ./Gayot/119_cereality-cereal-bar-and-cafe_review.csv
# ./Gayot/11_aigre-doux_review.csv
# ./Gayot/120_ceres-table_review.csv
# ./Gayot/121_cerise_review.csv
# ./Gayot/122_chalkboard_review.csv
# ./Gayot/123_charlies-ale-house_review.csv
# ./Gayot/545_x-o-chicago_review.csv
# ./Gayot/546_xel-ha_review.csv
# ./Gayot/550_zapatista_review.csv
# ./Gayot/551_thong-thai_review.csv
# ./Gayot/552_zealous-restaurant_review.csv
# ./Gayot/553_zed451_review.csv
# ./Gayot/554_zest_review.csv
# ./Gayot/555_osteria-la-madia_review.csv
# ./Gayot/556_zk-food_review.csv
# ./Gayot/557_zocalo_review.csv
# ./Gayot/558_zoom-kitchen_review.csv
# ./Gayot/55_bin-36_review.csv
# ./Gayot/56_bin-wine-cafe_review.csv
# ./Gayot/57_bistro-110_review.csv
# ./Gayot/58_bistro-dre_review.csv
# ./Gayot/59_bistro-750_review.csv
# ./Gayot/61_bistro-pacific_review.csv
# ./Gayot/62_bistrot-margot_review.csv
# ./Gayot/63_bistrot-zinc_review.csv
# ./Gayot/64_grizzlys-lodge_review.csv
# ./Gayot/65_blu-coral_review.csv
# ./Gayot/66_blue-door-farm-stand_review.csv
# ./Gayot/68_blue-ocean_review.csv
# ./Gayot/69_bluepoint-oyster-bar_review.csv
# ./Gayot/6_abbey-pub_review.csv
# ./Gayot/70_blue-water-grill_review.csv
# ./Gayot/71_the-bluebird_review.csv
# ./Gayot/72_bob-chinns-crabhouse-chicago_review.csv
# ./Gayot/73_bobtail-ice-cream-company_review.csv
# ./Gayot/74_bombay-spice-grill-and-wine_review.csv
# ./Gayot/75_boston-blackies_review.csv
# ./Gayot/76_the-brass-monkey_review.csv
# ./Gayot/77_brasserie-jo_review.csv
# ./Gayot/78_brasserie-ruhlmann_review.csv
# ./Gayot/79_bravo-tapas-and-lounge_review.csv
# ./Gayot/7_abril-mexican-restaurant-logan-square_review.csv
# ./Gayot/80_brazzaz_review.csv
# ./Gayot/81_bretts-cafe-americain_review.csv
# ./Gayot/83_brio_review.csv
# ./Gayot/84_brother-jimmys_review.csv
# ./Gayot/85_browntrout_review.csv
# ./Gayot/86_buca-di-beppo_review.csv
# ./Gayot/87_bucks-chicken-and-biscuits_review.csv
# ./Gayot/88_buongiorno-cafe_review.csv
# ./Gayot/89_the-burger-philosophy_review.csv
# ./Gayot/90_butter_review.csv
# ./Gayot/91_butter_review.csv
# ./Gayot/92_butterfield-8_review.csv
# ./Gayot/93_byrons-hot-dogs_review.csv
# ./Gayot/94_c-house_review.csv
# ./Gayot/96_cafe-apollo_review.csv
# ./Gayot/97_cafe-bernard_review.csv
# ./Gayot/98_cafe-bionda_review.csv
# ./Gayot/99_cafe-bolero_review.csv
# ./Gayot/9_adesso_review.csv

# %%
GetReviewNLP(path='./Tribune/')
# Out:
# ./Tribune/0_25-degrees_review.csv
# ./Tribune/100_salpicon_review.csv
# ./Tribune/101_salt-and-pepper-diner_review.csv
# ./Tribune/102_sams-red-hots_review.csv
# ./Tribune/102_sam’s-red-hots_review.csv
# ./Tribune/103_sarks-in-the-park_review.csv
# ./Tribune/104_seasons-52_review.csv
# ./Tribune/105_seven-the-den-and-manhole_review.csv
# ./Tribune/83_the-peasantry_review.csv
# ./Tribune/84_perennial-virant_review.csv
# ./Tribune/85_perrys-deli_review.csv
# ./Tribune/86_the-parthenon_review.csv
# ./Tribune/87_pi-gallery-bar_review.csv
# ./Tribune/88_piggyback-bbq_review.csv
# ./Tribune/89_pleasant-house-bakery_review.csv
# ./Tribune/8_b-bim-asian-eatery_review.csv
# ./Tribune/90_pork-shoppe_review.csv
# ./Tribune/91_q-bbq_review.csv
# ./Tribune/92_quay_review.csv
# ./Tribune/93_red-door_review.csv
# ./Tribune/94_red-ivy_review.csv
# ./Tribune/95_grande-noodles-and-sushi-bar_review.csv
# ./Tribune/95_red-robin_review.csv
# ./Tribune/96_rezas-restaurant_review.csv
# ./Tribune/97_riques-cocina-mexicana_review.csv
# ./Tribune/98_rose-angelis_review.csv
# ./Tribune/99_rosebud-theater-district_review.csv
# ./Tribune/9_baffo_review.csv

# %%
GetReviewNLP(path='./OpenRestaurants/')
# Out:
# ./OpenRestaurants/0_rockit-burger-bar-chicago_review.csv
# ./OpenRestaurants/1001_taqueria-san-jose-chicago_review.csv
# ./OpenRestaurants/1003_osteria-via-stato-chicago_review.csv
# ./OpenRestaurants/1004_las-picosas-chicago_review.csv
# ./OpenRestaurants/1005_the-little-india-chicago_review.csv
# ./OpenRestaurants/1007_green-zebra-chicago_review.csv
# ./OpenRestaurants/1013_dicks-last-resort-chicago-2_review.csv
# ./OpenRestaurants/1017_buona-terra-ristorante-chicago_review.csv
# ./OpenRestaurants/1023_paramount-room-chicago_review.csv
# ./OpenRestaurants/1025_foodlife-chicago_review.csv
# ./OpenRestaurants/1026_sheffields-wine-and-beer-garden-chicago_review.csv
# ./OpenRestaurants/1028_primehouse-chicago-2_review.csv
# ./OpenRestaurants/1033_iguana-café-chicago-2_review.csv
# ./OpenRestaurants/1034_lou-malnatis-pizzeria-chicago-4_review.csv
# ./OpenRestaurants/1037_d-amatos-bakery-chicago_review.csv
# ./OpenRestaurants/1038_flat-top-grill-chicago-7_review.csv
# ./OpenRestaurants/1039_merlo-on-maple-chicago_review.csv
# ./OpenRestaurants/1040_lees-chop-suey-chicago_review.csv
# ./OpenRestaurants/1041_twin-anchors-restaurant-and-tavern-chicago_review.csv
# ./OpenRestaurants/1044_state-restaurant-chicago_review.csv
# ./OpenRestaurants/1048_the-chicago-firehouse-restaurant-chicago_review.csv
# ./OpenRestaurants/1049_mercat-a-la-planxa-chicago_review.csv
# ./OpenRestaurants/104_mon-ami-gabi-chicago_review.csv
# ./OpenRestaurants/1050_flying-saucer-chicago_review.csv
# ./OpenRestaurants/1052_jj-fish-and-chicken-chicago-4_review.csv
# ./OpenRestaurants/1055_house-of-hunan-chicago_review.csv
# ./OpenRestaurants/1056_thai-aroma-chicago_review.csv
# ./OpenRestaurants/1057_laschets-inn-chicago-2_review.csv
# ./OpenRestaurants/1058_the-signature-room-at-the-95th-chicago-2_review.csv
# ./OpenRestaurants/105_annapurna-chicago_review.csv
# ./OpenRestaurants/1060_las-fuentes-restaurant-chicago_review.csv
# ./OpenRestaurants/1063_state-and-lake-chicago-tavern-chicago_review.csv
# ./OpenRestaurants/1064_the-rice-table-chicago_review.csv
# ./OpenRestaurants/1070_gamekeepers-tavern-and-grill-chicago_review.csv
# ./OpenRestaurants/1076_millers-pub-chicago_review.csv
# ./OpenRestaurants/1077_phoenix-restaurant-chicago_review.csv
# ./OpenRestaurants/1080_the-chicago-diner-chicago_review.csv
# ./OpenRestaurants/1081_cafe-selmarie-chicago_review.csv
# ./OpenRestaurants/1084_pueblito-viejo-chicago-2_review.csv
# ./OpenRestaurants/1085_old-jerusalem-chicago_review.csv
# ./OpenRestaurants/1086_sun-wah-bar-b-que-chicago-2_review.csv
# ./OpenRestaurants/1088_miss-asia-chicago_review.csv
# ./OpenRestaurants/1089_north-pond-chicago_review.csv
# ./OpenRestaurants/1090_rubys-fast-food-chicago_review.csv
# ./OpenRestaurants/1094_el-potosi-chicago_review.csv
# ./OpenRestaurants/109_greek-islands-restaurant-chicago_review.csv
# ./OpenRestaurants/1100_the-publican-chicago_review.csv
# ./OpenRestaurants/1101_lao-beijing-chicago_review.csv
# ./OpenRestaurants/1102_milk-and-honey-cafe-chicago_review.csv
# ./OpenRestaurants/1104_macello-chicago_review.csv
# ./OpenRestaurants/1105_the-italian-village-restaurants-chicago_review.csv
# ./OpenRestaurants/1107_anteprima-chicago_review.csv
# ./OpenRestaurants/1108_hamburger-marys-chicago-2_review.csv
# ./OpenRestaurants/1112_lokal-chicago_review.csv
# ./OpenRestaurants/1115_shamrock-club-chicago_review.csv
# ./OpenRestaurants/1116_el-mariachi-chicago_review.csv
# ./OpenRestaurants/111_yoshis-cafe-chicago_review.csv
# ./OpenRestaurants/1123_mindys-hot-chocolate-chicago-2_review.csv
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-8-ca85c7785471> in <module>()
# ----> 1 GetReviewNLP(path='./OpenRestaurants/')
#
# <ipython-input-5-fe33f94c992d> in GetReviewNLP(path)
#       3     for file in reviewfiles:
#       4         print(path+file)
# ----> 5         df = pd.read_csv(path+file)
#       6         if len(df.columns) == 3:
#       7             Sentiment = GetSentiment(df=df, column='text', prefix='')
#
# /Users/cysung/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /Users/cysung/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     409
#     410     try:
# --> 411         data = parser.read(nrows)
#     412     finally:
#     413         parser.close()
#
# /Users/cysung/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#     980                 raise ValueError('skipfooter not supported for iteration')
#     981
# --> 982         ret = self._engine.read(nrows)
#     983
#     984         if self.options.get('as_recarray'):
#
# /Users/cysung/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1717     def read(self, nrows=None):
#    1718         try:
# -> 1719             data = self._reader.read(nrows)
#    1720         except StopIteration:
#    1721             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read (pandas/_libs/parsers.c:10862)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory (pandas/_libs/parsers.c:11138)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows (pandas/_libs/parsers.c:11884)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows (pandas/_libs/parsers.c:11755)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error (pandas/_libs/parsers.c:28765)()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.

# %% [markdown]
# 1123_mindys-hot-chocolate-chicago-2_review_bad.csv

# %%
GetReviewNLP(path='./OpenRestaurants/')
# Out:
# ./OpenRestaurants/0_rockit-burger-bar-chicago_review.csv
# ./OpenRestaurants/1001_taqueria-san-jose-chicago_review.csv
# ./OpenRestaurants/1003_osteria-via-stato-chicago_review.csv
# ./OpenRestaurants/1004_las-picosas-chicago_review.csv
# ./OpenRestaurants/1005_the-little-india-chicago_review.csv
# ./OpenRestaurants/1007_green-zebra-chicago_review.csv
# ./OpenRestaurants/1013_dicks-last-resort-chicago-2_review.csv
# ./OpenRestaurants/1017_buona-terra-ristorante-chicago_review.csv
# ./OpenRestaurants/1023_paramount-room-chicago_review.csv
# ./OpenRestaurants/1025_foodlife-chicago_review.csv
# ./OpenRestaurants/1026_sheffields-wine-and-beer-garden-chicago_review.csv
# ./OpenRestaurants/1028_primehouse-chicago-2_review.csv
# ./OpenRestaurants/1033_iguana-café-chicago-2_review.csv
# ./OpenRestaurants/1034_lou-malnatis-pizzeria-chicago-4_review.csv
# ./OpenRestaurants/1037_d-amatos-bakery-chicago_review.csv
# ./OpenRestaurants/1038_flat-top-grill-chicago-7_review.csv
# ./OpenRestaurants/1039_merlo-on-maple-chicago_review.csv
# ./OpenRestaurants/1040_lees-chop-suey-chicago_review.csv
# ./OpenRestaurants/1041_twin-anchors-restaurant-and-tavern-chicago_review.csv
# ./OpenRestaurants/1044_state-restaurant-chicago_review.csv
# ./OpenRestaurants/1048_the-chicago-firehouse-restaurant-chicago_review.csv
# ./OpenRestaurants/1049_mercat-a-la-planxa-chicago_review.csv
# ./OpenRestaurants/104_mon-ami-gabi-chicago_review.csv
# ./OpenRestaurants/1050_flying-saucer-chicago_review.csv
# ./OpenRestaurants/1052_jj-fish-and-chicken-chicago-4_review.csv
# ./OpenRestaurants/1055_house-of-hunan-chicago_review.csv
# ./OpenRestaurants/1056_thai-aroma-chicago_review.csv
# ./OpenRestaurants/1057_laschets-inn-chicago-2_review.csv
# ./OpenRestaurants/1058_the-signature-room-at-the-95th-chicago-2_review.csv
# ./OpenRestaurants/105_annapurna-chicago_review.csv
# ./OpenRestaurants/1060_las-fuentes-restaurant-chicago_review.csv
# ./OpenRestaurants/1063_state-and-lake-chicago-tavern-chicago_review.csv
# ./OpenRestaurants/1064_the-rice-table-chicago_review.csv
# ./OpenRestaurants/1070_gamekeepers-tavern-and-grill-chicago_review.csv
# ./OpenRestaurants/1076_millers-pub-chicago_review.csv
# ./OpenRestaurants/1077_phoenix-restaurant-chicago_review.csv
# ./OpenRestaurants/1080_the-chicago-diner-chicago_review.csv
# ./OpenRestaurants/1081_cafe-selmarie-chicago_review.csv
# ./OpenRestaurants/1084_pueblito-viejo-chicago-2_review.csv
# ./OpenRestaurants/1085_old-jerusalem-chicago_review.csv
# ./OpenRestaurants/1086_sun-wah-bar-b-que-chicago-2_review.csv
# ./OpenRestaurants/1088_miss-asia-chicago_review.csv
# ./OpenRestaurants/1089_north-pond-chicago_review.csv
# ./OpenRestaurants/1090_rubys-fast-food-chicago_review.csv
# ./OpenRestaurants/1094_el-potosi-chicago_review.csv
# ./OpenRestaurants/109_greek-islands-restaurant-chicago_review.csv
# ./OpenRestaurants/1100_the-publican-chicago_review.csv
# ./OpenRestaurants/1101_lao-beijing-chicago_review.csv
# ./OpenRestaurants/1102_milk-and-honey-cafe-chicago_review.csv
# ./OpenRestaurants/1104_macello-chicago_review.csv
# ./OpenRestaurants/1105_the-italian-village-restaurants-chicago_review.csv
# ./OpenRestaurants/1107_anteprima-chicago_review.csv
# ./OpenRestaurants/1108_hamburger-marys-chicago-2_review.csv
# ./OpenRestaurants/1112_lokal-chicago_review.csv
# ./OpenRestaurants/1115_shamrock-club-chicago_review.csv
# ./OpenRestaurants/1116_el-mariachi-chicago_review.csv
# ./OpenRestaurants/111_yoshis-cafe-chicago_review.csv
# ./OpenRestaurants/1127_pizza-metro-chicago_review.csv
# ./OpenRestaurants/1128_mannys-cafeteria-and-delicatessen-chicago-3_review.csv
# ./OpenRestaurants/1129_martinez-supermarket-chicago_review.csv
# ./OpenRestaurants/1130_fuji-ya-harwood-heights_review.csv
# ./OpenRestaurants/1134_burrito-beach-chicago-6_review.csv
# ./OpenRestaurants/1142_taco-burrito-king-chicago-11_review.csv
# ./OpenRestaurants/1147_la-cabana-de-don-luis-chicago_review.csv
# ./OpenRestaurants/1151_russian-tea-time-chicago_review.csv
# ./OpenRestaurants/1154_viet-bowl-chicago_review.csv
# ./OpenRestaurants/1156_frontera-fresco-chicago_review.csv
# ./OpenRestaurants/1157_mity-nice-chicago-14_review.csv
# ./OpenRestaurants/1159_cite-chicago-4_review.csv
# ./OpenRestaurants/1160_taqueria-moran-chicago-3_review.csv
# ./OpenRestaurants/1167_sarpinos-pizzeria-chicago-4_review.csv
# ./OpenRestaurants/1168_las-tablas-colombian-steakhouse-chicago_review.csv
# ./OpenRestaurants/1171_kopi-travelers-cafe-chicago_review.csv
# ./OpenRestaurants/1172_gyro-stop-chicago_review.csv
# ./OpenRestaurants/1173_wing-hoe-restaurant-chicago_review.csv
# ./OpenRestaurants/1175_chicago-brauhaus-chicago_review.csv
# ./OpenRestaurants/1179_la-encantada-chicago_review.csv
# ./OpenRestaurants/117_topo-gigio-ristorante-chicago_review.csv
# ./OpenRestaurants/1180_bens-noodles-and-rice-chicago_review.csv
# ./OpenRestaurants/1182_alhambra-palace-chicago_review.csv
# ./OpenRestaurants/1183_la-bruquena-chicago_review.csv
# ./OpenRestaurants/1187_picante-taqueria-chicago-2_review.csv
# ./OpenRestaurants/1190_lou-malnatis-pizzeria-chicago-3_review.csv
# ./OpenRestaurants/1193_joys-noodles-and-rice-chicago_review.csv
# ./OpenRestaurants/1194_gaylord-fine-indian-cuisine-chicago-11_review.csv
# ./OpenRestaurants/1197_osaka-sushi-express-and-fresh-fruit-smoothies-chicago-2_review.csv
# ./OpenRestaurants/119_high-dive-chicago_review.csv
# ./OpenRestaurants/1202_frank-and-marys-tavern-chicago_review.csv
# ./OpenRestaurants/120_boka-chicago_review.csv
# ./OpenRestaurants/1212_hellas-gyros-chicago-2_review.csv
# ./OpenRestaurants/1213_cafe-el-tapatio-chicago-4_review.csv
# ./OpenRestaurants/1215_shokran-moroccan-restaurant-chicago_review.csv
# ./OpenRestaurants/1216_elephant-and-castle-chicago-5_review.csv
# ./OpenRestaurants/1217_taqueria-y-restaurant-el-gusto-chicago_review.csv
# ./OpenRestaurants/1219_shokolad-chicago_review.csv
# ./OpenRestaurants/121_wilde-bar-and-restaurant-chicago_review.csv
# ./OpenRestaurants/1220_svea-restaurant-chicago_review.csv
# ./OpenRestaurants/1222_la-cocina-chicago-7_review.csv
# ./OpenRestaurants/1229_clark-street-dog-chicago-2_review.csv
# ./OpenRestaurants/122_da-rae-jung-chicago_review.csv
# ./OpenRestaurants/1230_kikis-bistro-chicago_review.csv
# ./OpenRestaurants/1233_lucias-gourmet-italian-cuisine-chicago_review.csv
# ./OpenRestaurants/1234_emilios-tapas-sol-y-nieve-chicago-2_review.csv
# ./OpenRestaurants/1235_chicago-curry-house-chicago-6_review.csv
# ./OpenRestaurants/1237_la-bomba-chicago-4_review.csv
# ./OpenRestaurants/1239_lawrence-fish-market-chicago_review.csv
# ./OpenRestaurants/123_siam-noodle-and-rice-chicago_review.csv
# ./OpenRestaurants/1242_lbs-bistro-and-patisserie-chicago_review.csv
# ./OpenRestaurants/1243_villa-pizza-lincolnwood_review.csv
# ./OpenRestaurants/1245_taste-of-greece-chicago_review.csv
# ./OpenRestaurants/1248_standing-room-only-chicago_review.csv
# ./OpenRestaurants/1249_cornerstone-cafe-chicago_review.csv
# ./OpenRestaurants/1251_peking-chinese-food-chicago-2_review.csv
# ./OpenRestaurants/1252_pasteur-chicago_review.csv
# ./OpenRestaurants/1254_happiness-chicago_review.csv
# ./OpenRestaurants/1255_rockit-bar-and-grill-chicago_review.csv
# ./OpenRestaurants/1256_city-pool-hall-and-sports-bar-chicago_review.csv
# ./OpenRestaurants/1257_wingstop-chicago_review.csv
# ./OpenRestaurants/1258_tac-quick-chicago_review.csv
# ./OpenRestaurants/125_simply-it-chicago_review.csv
# ./OpenRestaurants/1260_sullivans-steakhouse-chicago_review.csv
# ./OpenRestaurants/1261_honky-tonk-bbq-chicago_review.csv
# ./OpenRestaurants/1262_the-map-room-chicago_review.csv
# ./OpenRestaurants/1264_f-o-mahonys-chicago_review.csv
# ./OpenRestaurants/1267_joy-yees-noodle-shop-chicago-2_review.csv
# ./OpenRestaurants/1271_room-22-chicago_review.csv
# ./OpenRestaurants/1272_basil-leaf-cafe-chicago_review.csv
# ./OpenRestaurants/1275_rosebud-steakhouse-chicago-4_review.csv
# ./OpenRestaurants/127_the-motel-bar-chicago_review.csv
# ./OpenRestaurants/1282_theory-chicago-2_review.csv
# ./OpenRestaurants/1284_taqueria-traspasada-chicago-2_review.csv
# ./OpenRestaurants/1285_south-water-kitchen-chicago_review.csv
# ./OpenRestaurants/1286_the-long-room-chicago_review.csv
# ./OpenRestaurants/1288_leons-famous-ribs-chicago-2_review.csv
# ./OpenRestaurants/1289_shawarma-inn-chicago_review.csv
# ./OpenRestaurants/1295_uncommon-ground-chicago-2_review.csv
# ./OpenRestaurants/1297_green-mill-chicago_review.csv
# ./OpenRestaurants/1300_les-pho-chicago_review.csv
# ./OpenRestaurants/1302_aruns-thai-restaurant-chicago_review.csv
# ./OpenRestaurants/1304_chi-cafe-chicago_review.csv
# ./OpenRestaurants/1307_golden-apple-grill-and-breakfast-house-chicago_review.csv
# ./OpenRestaurants/1309_naha-chicago_review.csv
# ./OpenRestaurants/1310_atinos-pizza-chicago_review.csv
# ./OpenRestaurants/1312_fado-irish-pub-and-restaurant-chicago-2_review.csv
# ./OpenRestaurants/1314_la-peña-restaurante-chicago_review.csv
# ./OpenRestaurants/1320_one-north-kitchen-and-bar-chicago_review.csv
# ./OpenRestaurants/1323_tempo-cafe-chicago_review.csv
# ./OpenRestaurants/1324_serbian-village-restaurant-chicago_review.csv
# ./OpenRestaurants/1328_tocco-chicago_review.csv
# ./OpenRestaurants/132_mercadito-chicago_review.csv
# ./OpenRestaurants/1330_harry-carays-italian-steakhouse-river-north-chicago-2_review.csv
# ./OpenRestaurants/1332_azucar-tapas-restaurant-and-cocktail-bar-chicago_review.csv
# ./OpenRestaurants/1336_fireplace-inn-chicago_review.csv
# ./OpenRestaurants/1340_azteca-grill-chicago-2_review.csv
# ./OpenRestaurants/1342_el-torito-restaurant-and-taqueria-chicago_review.csv
# ./OpenRestaurants/1344_pie-eyed-pizzeria-chicago_review.csv
# ./OpenRestaurants/1346_ringo-japanese-kitchen-chicago_review.csv
# ./OpenRestaurants/1347_janitzio-burrito-chicago_review.csv
# ./OpenRestaurants/134_rl-restaurant-chicago_review.csv
# ./OpenRestaurants/1352_bubba-gump-shrimp-chicago-4_review.csv
# ./OpenRestaurants/1358_jims-original-hot-dog-chicago_review.csv
# ./OpenRestaurants/1359_vito-and-angelos-pizzeria-and-restaurant-chicago-2_review.csv
# ./OpenRestaurants/135_mccormick-and-schmicks-chicago-3_review.csv
# ./OpenRestaurants/1361_la-oaxaqueña-chicago-4_review.csv
# ./OpenRestaurants/1362_la-crêperie-chicago-2_review.csv
# ./OpenRestaurants/1363_wongs-chinese-restaurant-chicago_review.csv
# ./OpenRestaurants/1365_original-pancake-house-chicago-3_review.csv
# ./OpenRestaurants/1366_mr-submarine-chicago-11_review.csv
# ./OpenRestaurants/1368_everest-chicago_review.csv
# ./OpenRestaurants/1370_ann-sather-restaurant-chicago-3_review.csv
# ./OpenRestaurants/1372_smoque-bbq-chicago_review.csv
# ./OpenRestaurants/1375_epic-burger-chicago_review.csv
# ./OpenRestaurants/1377_chef-shangri-la-north-riverside_review.csv
# ./OpenRestaurants/1379_sidebar-grille-chicago-2_review.csv
# ./OpenRestaurants/1380_siam-rice-chicago_review.csv
# ./OpenRestaurants/1383_white-palace-grill-chicago_review.csv
# ./OpenRestaurants/1384_estelles-chicago_review.csv
# ./OpenRestaurants/1385_little-corner-restaurant-chicago_review.csv
# ./OpenRestaurants/1386_red-june-chicago_review.csv
# ./OpenRestaurants/1387_the-waterfront-cafe-chicago_review.csv
# ./OpenRestaurants/1388_feed-chicago_review.csv
# ./OpenRestaurants/138_chicagos-dog-house-chicago-2_review.csv
# ./OpenRestaurants/1391_kincades-chicago_review.csv
# ./OpenRestaurants/1392_potbelly-sandwich-shop-chicago-37_review.csv
# ./OpenRestaurants/1397_me-dee-cafe-chicago_review.csv
# ./OpenRestaurants/1401_trader-todds-chicago_review.csv
# ./OpenRestaurants/1402_home-run-inn-pizza-archer-ave-chicago-3_review.csv
# ./OpenRestaurants/1404_folklore-argentine-grill-chicago_review.csv
# ./OpenRestaurants/1409_devil-dawgs-chicago_review.csv
# ./OpenRestaurants/1412_joes-seafood-prime-steak-and-stone-crab-chicago_review.csv
# ./OpenRestaurants/1413_westend-bar-and-grill-chicago_review.csv
# ./OpenRestaurants/1414_duke-of-perth-chicago_review.csv
# ./OpenRestaurants/1415_galway-arms-chicago_review.csv
# ./OpenRestaurants/1416_old-town-pub-chicago_review.csv
# ./OpenRestaurants/1419_joes-seafood-prime-steak-and-stone-crab-chicago_review.csv
# ./OpenRestaurants/141_a-taste-of-heaven-chicago_review.csv
# ./OpenRestaurants/1423_pita-grill-chicago_review.csv
# ./OpenRestaurants/1426_the-indian-garden-chicago-4_review.csv
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-ca85c7785471> in <module>()
# ----> 1 GetReviewNLP(path='./OpenRestaurants/')
#
# <ipython-input-5-fe33f94c992d> in GetReviewNLP(path)
#       3     for file in reviewfiles:
#       4         print(path+file)
# ----> 5         df = pd.read_csv(path+file)
#       6         if len(df.columns) == 3:
#       7             Sentiment = GetSentiment(df=df, column='text', prefix='')
#
# /Users/cysung/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /Users/cysung/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     409
#     410     try:
# --> 411         data = parser.read(nrows)
#     412     finally:
#     413         parser.close()
#
# /Users/cysung/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#     980                 raise ValueError('skipfooter not supported for iteration')
#     981
# --> 982         ret = self._engine.read(nrows)
#     983
#     984         if self.options.get('as_recarray'):
#
# /Users/cysung/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1717     def read(self, nrows=None):
#    1718         try:
# -> 1719             data = self._reader.read(nrows)
#    1720         except StopIteration:
#    1721             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read (pandas/_libs/parsers.c:10862)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory (pandas/_libs/parsers.c:11138)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows (pandas/_libs/parsers.c:11884)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows (pandas/_libs/parsers.c:11755)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error (pandas/_libs/parsers.c:28765)()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.

# %%
df = pd.read_csv('./Gayot/262_indian-garden_review.csv')

# %%
#def GetStats(csvfile=None):
df = pd.read_csv('2_42-grams_review.csv')

# %%
df.shape
# Out:
# (80, 3)

# %%
df
# Out:
#           date  star                                               text
# 0   2017-07-17   5.0  We are sad to hear of 42 grams closing. We had...
# 1   2017-05-16   5.0  A gold standard in fine dining.  Jake and Alex...
# 2   2017-04-25   5.0  Wow... this is an experience.    Probably top ...
# 3   2017-03-17   5.0  What an excellent dining experience! One of th...
# 4   2017-03-09   5.0  Of all the fine dining experiences I have had ...
# 5   2017-01-05   5.0  Overall , amazing. Food worth all the praise p...
# 71  2014-03-16   5.0  A simply amazing experience. Chef  Jake and hi...
# 72  2014-03-02   5.0  Enjoyed my time at the Chef's Counter on Frida...
# 73  2014-02-15   5.0  Simply a fantastic dining experience. Alexa an...
# 74  2014-02-09   5.0  The place is a welcome addition to the Uptown ...
# 75  2014-01-29   5.0  This was literally one of the best meals of my...
# 76  2014-01-22   5.0  My husband surprised me with dinner here to ce...
# 77  2014-01-16   5.0  just had a fabulous dinner. intimate setting a...
# 78  2014-01-13   5.0  Absolutely fantastic! We went with a group of ...
# 79  2014-01-11   5.0  I've heard great things about sous rising and ...
#
# [80 rows x 3 columns]

# %%
df.shape[0]
# Out:
# 80

# %%
last = df['date'][0]

# %%
type(last)
# Out:
# str

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 3 columns):
# date    80 non-null object
# star    80 non-null float64
# text    80 non-null object
# dtypes: float64(1), object(2)
# memory usage: 2.0+ KB

# %%
df['date'] =  pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 3 columns):
# date    80 non-null datetime64[ns]
# star    80 non-null float64
# text    80 non-null object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 2.0+ KB

# %%
df['date'][0]
# Out:
# Timestamp('2017-07-17 00:00:00')

# %%
daysago = 365
#td = timedelta(days=daysago)

# %%
timepoint = df['date'][0] - timedelta(days=daysago)

# %%
oneyago = df['date'][0] - td

# %%
df['date'][0] > ago
# Out:
# True

# %%
twoyago = df['date'][0] - timedelta(days=720)

# %%
oneyago
# Out:
# Timestamp('2016-07-17 00:00:00')

# %%
twoyago
# Out:
# Timestamp('2015-07-28 00:00:00')

# %%
twoyago > oneyago
# Out:
# False

# %%
recent = df[df['date'] > oneyago]

# %%
recent
# Out:
#          date  star                                               text
# 0  2017-07-17   5.0  We are sad to hear of 42 grams closing. We had...
# 1  2017-05-16   5.0  A gold standard in fine dining.  Jake and Alex...
# 2  2017-04-25   5.0  Wow... this is an experience.    Probably top ...
# 3  2017-03-17   5.0  What an excellent dining experience! One of th...
# 4  2017-03-09   5.0  Of all the fine dining experiences I have had ...
# 5  2017-01-05   5.0  Overall , amazing. Food worth all the praise p...
# 6  2016-12-03   5.0  Fantastic. Extremely personable between the ch...
# 7  2016-11-22   5.0  Absurd.  You will not forget eating here.  One...
# 8  2016-11-12   5.0  42 grams provides a unique dining experience t...
# 9  2016-11-11   4.0  went there last year for our anniversary last....
# 10 2016-11-10   3.0  Service was great, and the stories/description...
# 11 2016-11-09   5.0  14 April 2016 - We were very fortunate to get ...
# 12 2016-11-06   5.0  Celebrating our 6th anniversary with my hero's...
# 13 2016-11-06   1.0  I can't believe this place has 2 stars. Alexia...
# 14 2016-11-05   5.0  42 grams is crazy good! They deserve their two...
# 15 2016-11-03   1.0  we booked months in advance, of course they im...
# 16 2016-10-08   5.0  ***The very personal and intimate 42 grams is ...
# 17 2016-09-13   5.0  Wow. I made a reservation 3 months in advance ...
# 18 2016-09-05   5.0  A unique experience no doubt. Pretend you are ...
# 19 2016-08-11   5.0  This is a review tailored towards those among ...
# 20 2016-07-22   5.0  Loved Alexa and Jake. The setup is very comfor...

# %%
df.shape[0]
# Out:
# 80

# %%
oneyear = 365
twoyear = 730

# %%
timepoint1 = df['date'][0] - timedelta(days=oneyear)
timepoint2 = df['date'][0] - timedelta(days=twoyear)
recent = df[df['date'] > timepoint1]
if recent.shape[0] >= 50:
    df = recent.copy()
else:
    df = df[df['date'] > timepoint2]

# %%
df
# Out:
#          date  star                                               text
# 0  2017-07-17   5.0  We are sad to hear of 42 grams closing. We had...
# 1  2017-05-16   5.0  A gold standard in fine dining.  Jake and Alex...
# 2  2017-04-25   5.0  Wow... this is an experience.    Probably top ...
# 3  2017-03-17   5.0  What an excellent dining experience! One of th...
# 4  2017-03-09   5.0  Of all the fine dining experiences I have had ...
# 5  2017-01-05   5.0  Overall , amazing. Food worth all the praise p...
# 6  2016-12-03   5.0  Fantastic. Extremely personable between the ch...
# 7  2016-11-22   5.0  Absurd.  You will not forget eating here.  One...
# 8  2016-11-12   5.0  42 grams provides a unique dining experience t...
# 9  2016-11-11   4.0  went there last year for our anniversary last....
# 10 2016-11-10   3.0  Service was great, and the stories/description...
# 11 2016-11-09   5.0  14 April 2016 - We were very fortunate to get ...
# 12 2016-11-06   5.0  Celebrating our 6th anniversary with my hero's...
# 13 2016-11-06   1.0  I can't believe this place has 2 stars. Alexia...
# 14 2016-11-05   5.0  42 grams is crazy good! They deserve their two...
# 15 2016-11-03   1.0  we booked months in advance, of course they im...
# 16 2016-10-08   5.0  ***The very personal and intimate 42 grams is ...
# 17 2016-09-13   5.0  Wow. I made a reservation 3 months in advance ...
# 18 2016-09-05   5.0  A unique experience no doubt. Pretend you are ...
# 19 2016-08-11   5.0  This is a review tailored towards those among ...
# 20 2016-07-22   5.0  Loved Alexa and Jake. The setup is very comfor...
# 21 2016-06-30   5.0  Outstanding!  My friend and I have been trying...
# 22 2016-05-31   5.0  Amazing experience done by 2 very kind, friend...
# 23 2016-05-30   5.0  This was the best meal have had in Chicago in ...
# 24 2016-05-20   5.0  Been here before they got 2 Michelin stars.  B...
# 25 2016-04-26   3.0  Dined here on our recent trip to Chicago last ...
# 26 2016-03-21   5.0  when you think about the top 5 memorable meals...
# 27 2016-02-07   5.0  I would highly recommend eating at 42 grams; i...
# 28 2016-01-02   5.0  This review is LONG overdue. In short, the bes...
# 29 2015-12-15   4.0  There is a lot of good going on at 42 grams, a...
# 30 2015-12-11   5.0  Great food. Exotic taste. It's BYOB because th...
# 31 2015-12-03   4.0  It was more of a 3.5 but whatevs. Easy online ...
# 32 2015-10-15   5.0  Absolutely delicious.....the best meal so far ...
# 33 2015-10-13   4.0  OMG.   Just not sure it deserves the 5 stars. ...
# 34 2015-10-02   2.0  Disappointing.  Very rushed, for one thing.  T...
# 35 2015-08-16   5.0  Overall, I felt that 42 grams served the best ...
# 36 2015-07-30   5.0  Doesn't get much better than this.  13 courses...

# %%
if df.shape[0] > 50:
    timepoint = df['date'][0] - timedelta(days=daysago)
    recent = df[df['date'] > timepoint]
    if recent.shape[0] < 50
